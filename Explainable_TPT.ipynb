# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Datasets:
#
# - nimi pi - a dataset of toki pona words to several possible english translations
# - word freq - english words along with part of speech, sorted by frequency. We can approximate this with Zipf's law.
# - conceptnetw2v - a word vectorization based on semantic meaning. This will allow us to decide between candidates.
# - synonyms, definitions - English Dictionary and Thesaurus

# %%
#Word, Part of Speech (ranked by popularity)
freq = pd.read_csv("word-freq-top5000.csv")

#toki pona words and translations
toki = pd.read_csv("nimi_pi.csv")
tp_vocab = toki.TOKI.drop_duplicates().tolist()

tokisentences = pd.read_csv('tokisentences.csv')

#Word -> Synonyms. This is a graph, we can search it.
synonyms    = pd.read_csv("thesauri\synonyms.csv")
hypernyms    = pd.read_csv("thesauri\WordnetHypernyms.csv")
hyponyms    = pd.read_csv("thesauri\WordnetHyponyms.csv")
noundefs = pd.read_csv("thesauri\WordnetNouns.csv")
verbdefs = pd.read_csv("thesauri\WordnetVerbs.csv")
adjcdefs = pd.read_csv("thesauri\WordnetAdjectives.csv")
advbdefs = pd.read_csv("thesauri\WordnetAdverbs.csv")

nouns = freq[freq['Part of speech'] == 'Noun']['Word'].tolist()
#['year', 'people', 'way', 'day', 'man', 'thing', 'woman', 'life', 'child']

verbs = freq[freq['Part of speech'] == 'Verb']['Word'].tolist()
#['have', 'do', 'say', 'go', 'can', 'get', 'would', 'make', 'know']

adjcs = freq[freq['Part of speech'] == 'Adjective']['Word'].tolist()
#['new', 'good', 'high', 'old', 'great', 'big', 'American', 'small', 'large']

advbs = freq[freq['Part of speech'] == 'Adverb']['Word'].tolist()
#['not', "n't", 'up', 'so', 'out', 'just', 'now', 'how', 'then', 'more']

# %%
freq[freq['Part of speech'] == 'Article']['Word'].tolist()
# Out:
# ['the', 'a', 'his', 'their', 'her', 'my', 'your', 'its', 'our', 'no', 'every']

# %%
freq[freq['Part of speech'] == 'Determiner']['Word'].tolist()
# Out:
# ['this',
#  'that',
#  'what',
#  'all',
#  'which',
#  'some',
#  'these',
#  'more',
#  'many',
#  'those',
#  'any',
#  'another',
#  'much',
#  'own',
#  'same',
#  'such',
#  'few',
#  'most',
#  'each',
#  'both',
#  'several',
#  'former',
#  'whose',
#  'half',
#  'less',
#  'whatever',
#  'little',
#  'enough',
#  'fewer',
#  'either',
#  'latter',
#  'neither',
#  'matter',
#  'no']

# %% [markdown]
# Our data is split into 10 parts of speech:
#  - Nouns, Verbs, and Adjectives - the meat of it
#  - Adverbs - basically just adjectives conjugated differently. I cannot stand adverbs.
#  - Prepositions, Conjunctions, Pronouns, Exclamations, Determiners, Measures - Toki Pona only has a few of these, as described below.

# %%
# THESE PARTS OF SPEECH ARE FAIRLY SIMPLE TO TRANSLATE

# <DETERMINER> := ali  - all, every, full, infinite
#                 mute - many, more
#                 ni - this, that
#                 seme - what, which

detes = freq[freq['Part of speech'] == 'Determiner']['Word'].tolist()
#['that', 'what', 'all', 'which', 'some', 'these', 'more', 'many', 'those']

# <PREPOSITION> := sewi - above, top
#                  anpa - below, bottom
#                  monsi - back, behind
#                  poka - in front of, next to, beside
#                  insa - inside, between, centered
#                  kama - coming, future, eventual
#                  awen - continuing, present, stay, constant
#                  tawa - toward, past, for
#                  ipa  - part, portion, segment, some
#                  teje - left
#                  soto - right
#                  lon  - true, on, at, in

preps = freq[freq['Part of speech'] == 'Preposition']['Word'].tolist()
#['in', 'to', 'for', 'with', 'on', 'at', 'from', 'by', 'about']

# <NUMBER> := nanpa - number, ordinal suffix
#             lo  - 0, none, empty
#             wan - 1
#             tu  - 2            
#             sa  - 3            
#             po  - 4            
#             ki  - 5   
#   Base six, so po po ki = 445_6 = 5  +  4*6  +  4 * 6^2 = 173 

meass = freq[freq['Part of speech'] == 'Measure']['Word'].tolist()
#['two', 'first', 'last', 'three', 'next', 'million', 'four', 'five', 'second']

# <INTERJECTION> := a - ah!, !, realization, laughter, bravo
#                   mu - meow, moo, animal noise
#                   n - hmm, wow, woah
#                   ajo - hello, hi
#                   tata - goodbye
#                   wa - oh, uh, well, conversational styrofoam
#                   ak - frustation, ouch, fuck (of aversion), sudden fear
#                   ja - yes

excls = freq[freq['Part of speech'] == 'Exclamation']['Word'].tolist()
#['oh', 'yeah', 'no', 'hey', 'hi', 'hello', 'mm-hmm', 'ah', 'wow']

# <PRONOUNS> := ijo - thing, event, object, matter, something, stuff
#               ona - he, she, it, they 
#               mi - I, me, we, us
#               sina - you 

prons = freq[freq['Part of speech'] == 'Pronoun']['Word'].tolist()
#['it', 'I', 'you', 'he', 'they', 'we', 'she', 'who', 'them']

# <CONJUNCTION> := sama - same, similar
#                  ante - different, other
#                  anu - or, minus, intersection, minimum
#                  en  - and, plus, union, maximum     
#                  taso - but, however                 
#                  tan  - by, from, times, because of, x tan y -> if y then x
#                  powe - false, pretend, imposter
#                  ala  - no, not


conjs = freq[freq['Part of speech'] == 'Conjunction']['Word'].tolist()
#['that', 'but', 'or', 'as', 'if', 'when', 'than', 'because', 'while']

# %%
adjcs
# Out:
# ['other',
#  'new',
#  'good',
#  'high',
#  'old',
#  'great',
#  'big',
#  'American',
#  'small',
#  'large',
#  'national',
#  'young',
#  'different',
#  'black',
#  'long',
#  'little',
#  'important',
#  'political',
#  'bad',
#  'white',
#  'real',
#  'best',
#  'right',
#  'social',
#  'only',
#  'public',
#  'sure',
#  'low',
#  'early',
#  'able',
#  'human',
#  'local',
#  'late',
#  'hard',
#  'major',
#  'better',
#  'economic',
#  'strong',
#  'possible',
#  'whole',
#  'free',
#  'military',
#  'true',
#  'federal',
#  'international',
#  'full',
#  'special',
#  'easy',
#  'clear',
#  'recent',
#  'certain',
#  'personal',
#  'open',
#  'red',
#  'difficult',
#  'available',
#  'likely',
#  'short',
#  'single',
#  'medical',
#  'current',
#  'wrong',
#  'private',
#  'past',
#  'foreign',
#  'fine',
#  'common',
#  'poor',
#  'natural',
#  'significant',
#  'similar',
#  'hot',
#  'dead',
#  'central',
#  'happy',
#  'serious',
#  'ready',
#  'simple',
#  'left',
#  'physical',
#  'general',
#  'environmental',
#  'financial',
#  'blue',
#  'democratic',
#  'dark',
#  'various',
#  'entire',
#  'close',
#  'legal',
#  'religious',
#  'cold',
#  'final',
#  'main',
#  'green',
#  'nice',
#  'huge',
#  'popular',
#  'traditional',
#  'cultural',
#  'wide',
#  'particular',
#  'top',
#  'far',
#  'deep',
#  'individual',
#  'specific',
#  'necessary',
#  'middle',
#  'beautiful',
#  'heavy',
#  'sexual',
#  'tough',
#  'commercial',
#  'total',
#  'modern',
#  'positive',
#  'civil',
#  'safe',
#  'interesting',
#  'rich',
#  'western',
#  'senior',
#  'key',
#  'professional',
#  'successful',
#  'southern',
#  'fresh',
#  'global',
#  'critical',
#  'concerned',
#  'effective',
#  'original',
#  'basic',
#  'powerful',
#  'perfect',
#  'involved',
#  'nuclear',
#  'British',
#  'African',
#  'very',
#  'sorry',
#  'normal',
#  'Chinese',
#  'front',
#  'supposed',
#  'Soviet',
#  'future',
#  'potential',
#  'European',
#  'independent',
#  'Christian',
#  'willing',
#  'previous',
#  'interested',
#  'wild',
#  'average',
#  'quick',
#  'light',
#  'bright',
#  'tiny',
#  'additional',
#  'present',
#  'warm',
#  'annual',
#  'French',
#  'responsible',
#  'regular',
#  'soft',
#  'female',
#  'afraid',
#  'native',
#  'broad',
#  'wonderful',
#  'growing',
#  'Indian',
#  'quiet',
#  'aware',
#  'complete',
#  'active',
#  'chief',
#  'cool',
#  'dangerous',
#  'moral',
#  'United',
#  'academic',
#  'healthy',
#  'negative',
#  'following',
#  'historical',
#  'direct',
#  'daily',
#  'fair',
#  'famous',
#  'familiar',
#  'appropriate',
#  'eastern',
#  'primary',
#  'clean',
#  'tall',
#  'male',
#  'alive',
#  'extra',
#  'domestic',
#  'northern',
#  'dry',
#  'Russian',
#  'sweet',
#  'corporate',
#  'strange',
#  'urban',
#  'mental',
#  'educational',
#  'favorite',
#  'greatest',
#  'complex',
#  'scientific',
#  'impossible',
#  'married',
#  'alone',
#  'presidential',
#  'emotional',
#  'Supreme',
#  'thin',
#  'empty',
#  'regional',
#  'Iraqi',
#  'expensive',
#  'yellow',
#  'prime',
#  'like',
#  'obvious',
#  'comfortable',
#  'angry',
#  'Japanese',
#  'thick',
#  'unique',
#  'internal',
#  'ethnic',
#  'actual',
#  'sick',
#  'Catholic',
#  'long-term',
#  'slow',
#  'brown',
#  'standard',
#  'English',
#  'funny',
#  'correct',
#  'Jewish',
#  'crazy',
#  'just',
#  'ancient',
#  'golden',
#  'German',
#  'used',
#  'equal',
#  'official',
#  'typical',
#  'conservative',
#  'smart',
#  'rare',
#  'separate',
#  'mean',
#  'industrial',
#  'surprised',
#  'busy',
#  'cheap',
#  'gray',
#  'overall',
#  'initial',
#  'terrible',
#  'contemporary',
#  'multiple',
#  'essential',
#  'criminal',
#  'careful',
#  'upper',
#  'tired',
#  'vast',
#  'limited',
#  'proud',
#  'increased',
#  'enormous',
#  'liberal',
#  'massive',
#  'rural',
#  'narrow',
#  'solid',
#  'useful',
#  'secret',
#  'unusual',
#  'sharp',
#  'creative',
#  'outside',
#  'gay',
#  'proper',
#  'live',
#  'guilty',
#  'living',
#  'technical',
#  'weak',
#  'illegal',
#  'fun',
#  'Israeli',
#  'spiritual',
#  'musical',
#  'dramatic',
#  'excellent',
#  'lucky',
#  'unable',
#  'sad',
#  'brief',
#  'existing',
#  'remaining',
#  'visual',
#  'violent',
#  'silent',
#  'later',
#  'immediate',
#  'mass',
#  'leading',
#  'Arab',
#  'double',
#  'Spanish',
#  'formal',
#  'joint',
#  'opposite',
#  'consistent',
#  'grand',
#  'racial',
#  'Mexican',
#  'online',
#  'glad',
#  'ordinary',
#  'numerous',
#  'practical',
#  'amazing',
#  'intense',
#  'visible',
#  'competitive',
#  'congressional',
#  'fundamental',
#  'severe',
#  'fat',
#  'still',
#  'Asian',
#  'digital',
#  'usual',
#  'psychological',
#  'increasing',
#  'holy',
#  'so-called',
#  'constant',
#  'capable',
#  'nervous',
#  'crucial',
#  'electronic',
#  'pure',
#  'fellow',
#  'smooth',
#  'nearby',
#  'inner',
#  'junior',
#  'due',
#  'straight',
#  'pretty',
#  'permanent',
#  'wet',
#  'pink',
#  'historic',
#  'apparent',
#  'sensitive',
#  'reasonable',
#  'wooden',
#  'elementary',
#  'aggressive',
#  'false',
#  'extreme',
#  'Latin',
#  'honest',
#  'Palestinian',
#  'giant',
#  'substantial',
#  'conventional',
#  'fast',
#  'biological',
#  'flat',
#  'mad',
#  'alternative',
#  'armed',
#  'clinical',
#  'Muslim',
#  'Islamic',
#  'ultimate',
#  'valuable',
#  'minor',
#  'developing',
#  'classic',
#  'extraordinary',
#  'rough',
#  'pregnant',
#  'distant',
#  'Italian',
#  'Canadian',
#  'universal',
#  'super',
#  'bottom',
#  'lost',
#  'unlikely',
#  'constitutional',
#  'broken',
#  'electric',
#  'literary',
#  'stupid',
#  'strategic',
#  'remarkable',
#  'blind',
#  'genetic',
#  'chemical',
#  'accurate',
#  'Olympic',
#  'odd',
#  'tight',
#  'solar',
#  'square',
#  'complicated',
#  'friendly',
#  'tremendous',
#  'innocent',
#  'remote',
#  'raw',
#  'surprising',
#  'mutual',
#  'advanced',
#  'attractive',
#  'diverse',
#  'relevant',
#  'ideal',
#  'working',
#  'unknown',
#  'assistant',
#  'extensive',
#  'loose',
#  'considerable',
#  'intellectual',
#  'external',
#  'confident',
#  'sudden',
#  'dirty',
#  'defensive',
#  'comprehensive',
#  'prominent',
#  'stable',
#  'elderly',
#  'steady',
#  'vital',
#  'mere',
#  'exciting',
#  'radical',
#  'Irish',
#  'pale',
#  'round',
#  'ill',
#  'vulnerable',
#  'scared',
#  'ongoing',
#  'athletic',
#  'slight',
#  'efficient',
#  'closer',
#  'wealthy',
#  'given',
#  'OK',
#  'incredible',
#  'rapid',
#  'painful',
#  'helpful',
#  'organic',
#  'proposed',
#  'sophisticated',
#  'asleep',
#  'controversial',
#  'desperate',
#  'loud',
#  'sufficient',
#  'modest',
#  'agricultural',
#  'curious',
#  'downtown',
#  'eager',
#  'detailed',
#  'romantic',
#  'orange',
#  'temporary',
#  'relative',
#  'brilliant',
#  'absolute',
#  'offensive',
#  'terrorist',
#  'dominant',
#  'hungry',
#  'naked',
#  'legitimate',
#  'dependent',
#  'institutional',
#  'civilian',
#  'weekly',
#  'wise',
#  'gifted',
#  'firm',
#  'running',
#  'distinct',
#  'artistic',
#  'impressive',
#  'ugly',
#  'worried',
#  'moderate',
#  'subsequent',
#  'continued',
#  'frequent',
#  'awful',
#  'widespread',
#  'lovely',
#  'everyday',
#  'adequate',
#  'principal',
#  'concrete',
#  'African-American',
#  'changing',
#  'colonial',
#  'dear',
#  'sacred',
#  'cognitive',
#  'collective',
#  'exact',
#  'okay',
#  'homeless',
#  'gentle',
#  'related',
#  'fit',
#  'magic',
#  'superior',
#  'acceptable',
#  'continuous',
#  'excited',
#  'bitter',
#  'bare',
#  'subtle',
#  'pleased',
#  'ethical',
#  'secondary',
#  'experimental',
#  'net',
#  'evident',
#  'harsh',
#  'suburban',
#  'retail',
#  'classical',
#  'estimated',
#  'patient',
#  'missing',
#  'reliable',
#  'Roman',
#  'occasional',
#  'administrative',
#  'deadly',
#  'Hispanic',
#  'monthly',
#  'Korean',
#  'mainstream',
#  'unlike',
#  'longtime',
#  'legislative',
#  'plain',
#  'strict',
#  'inevitable',
#  'unexpected',
#  'overwhelming',
#  'written',
#  'maximum',
#  'medium',
#  'outdoor',
#  'random',
#  'minimum',
#  'fiscal',
#  'uncomfortable',
#  'welcome',
#  'continuing',
#  'chronic',
#  'peaceful',
#  'retired',
#  'grateful',
#  'virtual',
#  'indigenous',
#  'closed',
#  'weird',
#  'outer',
#  'drunk',
#  'intelligent',
#  'convinced',
#  'driving',
#  'endless',
#  'mechanical',
#  'profound',
#  'genuine',
#  'horrible',
#  'behavioral',
#  'exclusive',
#  'meaningful',
#  'technological',
#  'pleasant',
#  'frozen',
#  'theoretical',
#  'delicate',
#  'electrical',
#  'invisible',
#  'mild',
#  'identical',
#  'precise',
#  'anxious',
#  'structural',
#  'residential',
#  'nonprofit',
#  'handsome',
#  'promising',
#  'conscious',
#  'evil',
#  'teenage',
#  'decent',
#  'oral',
#  'generous',
#  'purple',
#  'bold',
#  'reluctant',
#  'judicial',
#  'full-time',
#  'regulatory',
#  'diplomatic',
#  'elegant',
#  'interior',
#  'casual',
#  'productive',
#  'civic',
#  'steep',
#  'dynamic',
#  'scary',
#  'disappointed',
#  'precious',
#  'representative',
#  'content',
#  'realistic',
#  'hidden',
#  'tender',
#  'outstanding',
#  'lonely',
#  'artificial',
#  'abstract',
#  'silly',
#  'shared',
#  'revolutionary',
#  'rear',
#  'coastal',
#  'burning',
#  'verbal',
#  'tribal',
#  'ridiculous',
#  'automatic',
#  'divine',
#  'Dutch',
#  'Greek',
#  'talented',
#  'stiff',
#  'extended',
#  'toxic',
#  'alleged',
#  'mysterious',
#  'parental',
#  'protective',
#  'faint',
#  'shallow',
#  'improved',
#  'bloody',
#  'associated',
#  'near',
#  'optimistic',
#  'symbolic',
#  'hostile',
#  'combined',
#  'mixed',
#  'tropical',
#  'spectacular',
#  'sheer',
#  'prior',
#  'immune',
#  'exotic',
#  'fascinating',
#  'secure',
#  'ideological',
#  'secular',
#  'intimate',
#  'neutral',
#  'flexible',
#  'progressive',
#  'terrific',
#  'functional',
#  'cooperative',
#  'tragic',
#  'underlying',
#  'sexy',
#  'costly',
#  'ambitious',
#  'influential',
#  'uncertain',
#  'statistical',
#  'metropolitan',
#  'rolling',
#  'aesthetic',
#  'expected',
#  'royal',
#  'minimal',
#  'anonymous',
#  'instructional',
#  'fixed',
#  'experienced',
#  'upset',
#  'cute',
#  'short-term',
#  'passing',
#  'known',
#  'encouraging',
#  'accessible',
#  'dried',
#  'pro',
#  'well-known',
#  'surrounding',
#  'ecological',
#  'unprecedented',
#  'preliminary',
#  'shy',
#  'disabled',
#  'gross',
#  'damn',
#  'associate',
#  'innovative',
#  'vertical',
#  'instant',
#  'required',
#  'colorful',
#  'organizational',
#  'nasty',
#  'emerging',
#  'fierce',
#  'rational',
#  'vocal',
#  'unfair',
#  'risky',
#  'depressed',
#  'closest',
#  'supportive',
#  'informal',
#  'Persian',
#  'perceived',
#  'sole',
#  'partial',
#  'added',
#  'excessive',
#  'high-tech',
#  'logical',
#  'blank',
#  'dying',
#  'developmental',
#  'faster',
#  'striking',
#  'embarrassed',
#  'fucking',
#  'isolated',
#  'suspicious',
#  'eligible',
#  'demographic',
#  'intact',
#  'elaborate',
#  'comparable',
#  'awake',
#  'feminist',
#  'dumb',
#  'philosophical',
#  'municipal',
#  'neat',
#  'mobile',
#  'brutal',
#  'voluntary',
#  'valid',
#  'unhappy',
#  'coming',
#  'distinctive',
#  'calm',
#  'theological',
#  'fragile',
#  'old-fashioned',
#  'crowded',
#  'fantastic',
#  'level',
#  'liquid',
#  'suitable',
#  'cruel',
#  'loyal',
#  'rubber',
#  'favorable',
#  'veteran',
#  'integrated',
#  'blond',
#  'explicit',
#  'disturbing',
#  'magnetic',
#  'devastating',
#  'neighboring',
#  'consecutive',
#  'republican',
#  'worldwide',
#  'brave',
#  'dense',
#  'sunny',
#  'compelling',
#  'troubled',
#  'balanced',
#  'flying',
#  'sustainable',
#  'skilled',
#  'managing',
#  'marine',
#  'organized',
#  'boring',
#  'fatal',
#  'inherent',
#  'selected',
#  'naval',
#  'middle-class']

# %% [markdown]
# For each word, we associate to both its definition and synonyms

# %%
merged_data_nouns = pd.merge(noundefs, synonyms,          left_on='Word',  right_on='word', how='inner')
merged_data_nouns = pd.merge(merged_data_nouns, hyponyms,  left_on='Word', right_on='lemma', how='inner')
merged_data_nouns = pd.merge(merged_data_nouns, hypernyms, left_on='Word', right_on='lemma', how='inner')
merged_data_verbs = pd.merge(verbdefs, synonyms, left_on='Word',           right_on='word', how='inner')
merged_data_verbs = pd.merge(merged_data_verbs, hyponyms, left_on='Word',  right_on='lemma', how='inner')
merged_data_verbs = pd.merge(merged_data_verbs, hypernyms, left_on='Word', right_on='lemma', how='inner')
merged_data_adjcs = pd.merge(adjcdefs, synonyms, left_on='Word',           right_on='word', how='inner')
merged_data_adjcs = pd.merge(merged_data_adjcs, hyponyms, left_on='Word',  right_on='lemma', how='inner')
merged_data_adjcs = pd.merge(merged_data_adjcs, hypernyms, left_on='Word', right_on='lemma', how='inner')

# Filter rows where 'Definition' and at least one of 'synonyms', 'hyponyms', or 'hypernyms' is not null
filtered_data_nouns = merged_data_nouns[~(merged_data_nouns['Definition'].isnull() | merged_data_nouns['synonyms'].isnull() | merged_data_nouns['hyponyms'].isnull() | merged_data_nouns['hypernyms'].isnull())]
toDefNouns      = dict(zip(filtered_data_nouns['Word'], zip(filtered_data_nouns['Definition'].tolist(), filtered_data_nouns[['synonyms', 'hyponyms', 'hypernyms']].apply(lambda x: x.str.replace('|', ';').str.split(';')).values.tolist())))

filtered_data_verbs = merged_data_verbs[~(merged_data_verbs['Definition'].isnull() | merged_data_verbs['synonyms'].isnull() | merged_data_verbs['hyponyms'].isnull() | merged_data_verbs['hypernyms'].isnull())]
toDefVerbs      = dict(zip(filtered_data_verbs['Word'], zip(filtered_data_verbs['Definition'].tolist(), filtered_data_verbs[['synonyms', 'hyponyms', 'hypernyms']].apply(lambda x: x.str.replace('|', ';').str.split(';')).values.tolist())))

filtered_data_adjcs = merged_data_adjcs[~(merged_data_adjcs['Definition'].isnull() | merged_data_adjcs['synonyms'].isnull() | merged_data_adjcs['hyponyms'].isnull() | merged_data_adjcs['hypernyms'].isnull())]
toDefAdjectives = dict(zip(filtered_data_adjcs['Word'], zip(filtered_data_adjcs['Definition'].tolist(), filtered_data_adjcs[['synonyms', 'hyponyms', 'hypernyms']].apply(lambda x: x.str.replace('|', ';').str.split(';')).values.tolist())))
# Out:
# C:\Users\night\AppData\Local\Temp\ipykernel_20096\3022300548.py:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   toDefNouns      = dict(zip(filtered_data_nouns['Word'], zip(filtered_data_nouns['Definition'].tolist(), filtered_data_nouns[['synonyms', 'hyponyms', 'hypernyms']].apply(lambda x: x.str.replace('|', ';').str.split(';')).values.tolist())))
# C:\Users\night\AppData\Local\Temp\ipykernel_20096\3022300548.py:16: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   toDefVerbs      = dict(zip(filtered_data_verbs['Word'], zip(filtered_data_verbs['Definition'].tolist(), filtered_data_verbs[['synonyms', 'hyponyms', 'hypernyms']].apply(lambda x: x.str.replace('|', ';').str.split(';')).values.tolist())))
# C:\Users\night\AppData\Local\Temp\ipykernel_20096\3022300548.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   toDefAdjectives = dict(zip(filtered_data_adjcs['Word'], zip(filtered_data_adjcs['Definition'].tolist(), filtered_data_adjcs[['synonyms', 'hyponyms', 'hypernyms']].apply(lambda x: x.str.replace('|', ';').str.split(';')).values.tolist())))

# %%
toDefNouns['lozenge'] #->

# Definition('a small aromatic or medicated candy',
# Synonyms  [['pill', 'tablet', 'tab'],
# Instances  ['cachou', 'cough drop', 'bolus', 'capsule', 'dragee', 'sleeping pill'],
# Categories  ['candy', 'dose']])
# Out:
# ('a small aromatic or medicated candy',
#  [['pill', 'tablet', 'tab'],
#   ['cachou', 'cough drop', 'bolus', 'capsule', 'dragee', 'sleeping pill'],
#   ['candy', 'dose']])

# %%
toDefNouns['week']
# Out:
# ('any period of seven consecutive days; it rained for a week',
#  [['hebdomad', 'workweek', 'calendar week'],
#   ['holy week', 'rag', 'shiva', 'week from monday'],
#   ['time period', 'work time', 'time period']])

# %% [markdown]
# For each toki word, we associate to all valid translations (ignoring part of speech for now). Two dictionaries going both ways here.

# %%
tokidict = dict()
for i in range(len(toki)):
    l = list(toki.loc[i])
    if l[0] in tokidict:
        tokidict[l[0]] += [x for x in l[2:] if str(x) == x]
    else:
        tokidict[l[0]]  = [x for x in l[2:] if str(x) == x]

# %%
tokidict['palisa']
# Out:
# ['long',
#  'long hard thing; branch',
#  'rod',
#  'stick',
#  'pointy thing',
#  'stretch',
#  'beat',
#  'poke',
#  'stab',
#  'sexually arouse']

# %%
edict = dict()
for k in tokidict:
    for v in tokidict[k]:
        edict[v] = k

edict['reptile']
# Out:
# 'akesi'

# %% [markdown]
# Naive method: Attempt to translate words, synonyms, and definitions into Toki Pona.

# %%
tok2eng_level_0 = dict([(n, []) for n in nouns + verbs + adjcs + advbs])

# %%
tok2eng_level_1 = tok2eng_level_0
for k in tokidict:
    for en in tokidict[k]:
        if en in tok2eng_level_1:
            if k not in tok2eng_level_1[en]:
                tok2eng_level_1[en].append(k)

# %%
fs = {}
for key in tok2eng_level_0:
    if tok2eng_level_1[key] != '':
        fs[key] = tok2eng_level_0[key]
fs
# Out:
# {'time': ['tenpo'],
#  'year': [],
#  'people': ['jan', 'kulupu'],
#  'way': ['nasin'],
#  'day': [],
#  'man': ['mije'],
#  'thing': ['ijo'],
#  'woman': ['meli'],
#  'life': ['konwe'],
#  'child': [],
#  'world': [],
#  'school': [],
#  'state': [],
#  'family': [],
#  'student': [],
#  'group': ['kulupu'],
#  'country': ['ma'],
#  'problem': [],
#  'hand': ['luka'],
#  'part': ['ipa'],
#  'place': ['jeno'],
#  'case': [],
#  'week': [],
#  'company': ['kulupu'],
#  'system': ['nasin'],
#  'program': [],
#  'question': [],
#  'work': ['pali'],
#  'government': [],
#  'number': ['nanpa'],
#  'night': [],
#  'Mr': [],
#  'point': [],
#  'home': ['tomo'],
#  'water': ['telo'],
#  'room': ['tomo'],
#  'mother': ['mama'],
#  'area': [],
#  'money': ['mani'],
#  'story': [],
#  'fact': ['kin'],
#  'month': [],
#  'lot': [],
#  'right': ['pona'],
#  'study': ['sona'],
#  'book': ['lipu'],
#  'eye': ['oko'],
#  'job': [],
#  'word': ['nimi'],
#  'business': ['esun'],
#  'issue': [],
#  'side': ['poka'],
#  'kind': [],
#  'head': ['lawa'],
#  'house': [],
#  'service': [],
#  'friend': [],
#  'father': ['mama'],
#  'power': ['wawa'],
#  'hour': [],
#  'game': ['musi'],
#  'line': ['linja'],
#  'end': ['pake', 'pini'],
#  'member': [],
#  'law': [],
#  'car': [],
#  'city': [],
#  'community': ['kulupu'],
#  'name': ['nimi'],
#  'president': [],
#  'team': [],
#  'minute': [],
#  'idea': [],
#  'kid': [],
#  'body': [],
#  'information': [],
#  'back': ['monsi'],
#  'parent': ['mama'],
#  'face': ['sinpin'],
#  'others': [],
#  'level': ['jeno'],
#  'office': [],
#  'door': ['lupa'],
#  'health': [],
#  'person': ['jan'],
#  'art': ['musi'],
#  'war': ['utala'],
#  'history': [],
#  'party': [],
#  'result': [],
#  'change': ['ante'],
#  'morning': [],
#  'reason': ['waleja'],
#  'research': [],
#  'girl': ['meli'],
#  'guy': [],
#  'food': ['moku'],
#  'moment': ['tenpo'],
#  'air': ['kon'],
#  'teacher': [],
#  'force': [],
#  'education': [],
#  'foot': [],
#  'boy': [],
#  'age': [],
#  'policy': [],
#  'process': [],
#  'music': [],
#  'market': ['esun'],
#  'sense': ['pilin'],
#  'nation': [],
#  'plan': [],
#  'college': [],
#  'interest': [],
#  'death': ['moli'],
#  'experience': [],
#  'effect': [],
#  'use': ['kepen'],
#  'class': [],
#  'control': ['lawa'],
#  'care': [],
#  'field': [],
#  'development': [],
#  'role': [],
#  'effort': [],
#  'rate': [],
#  'heart': [],
#  'drug': [],
#  'show': [],
#  'leader': [],
#  'light': ['pika', 'suno'],
#  'voice': ['kalama'],
#  'wife': ['meli'],
#  'police': [],
#  'mind': ['lawa'],
#  'price': [],
#  'report': [],
#  'decision': [],
#  'son': [],
#  'view': ['lukin'],
#  'relationship': [],
#  'town': [],
#  'road': ['nasin'],
#  'arm': ['luka'],
#  'difference': ['ante'],
#  'value': [],
#  'building': ['tomo'],
#  'action': [],
#  'model': [],
#  'season': [],
#  'society': ['kulupu'],
#  'tax': [],
#  'director': [],
#  'position': ['jeno'],
#  'player': [],
#  'record': [],
#  'paper': ['lipu'],
#  'space': ['naja'],
#  'ground': [],
#  'form': [],
#  'event': ['kama'],
#  'official': [],
#  'matter': [],
#  'center': [],
#  'couple': [],
#  'site': [],
#  'project': ['pali'],
#  'activity': ['pali'],
#  'star': ['mun'],
#  'table': ['supa'],
#  'need': ['wile'],
#  'court': [],
#  'American': [],
#  'oil': ['ojele'],
#  'situation': ['tenpo'],
#  'cost': [],
#  'industry': [],
#  'figure': [],
#  'street': [],
#  'image': ['sitelen'],
#  'phone': [],
#  'data': [],
#  'picture': ['sitelen'],
#  'practice': [],
#  'piece': [],
#  'land': ['ma'],
#  'product': [],
#  'doctor': [],
#  'wall': ['sinpin'],
#  'patient': [],
#  'worker': [],
#  'news': ['sin'],
#  'test': [],
#  'movie': [],
#  'north': [],
#  'love': ['olin'],
#  'support': [],
#  'technology': [],
#  'step': [],
#  'baby': [],
#  'computer': [],
#  'type': [],
#  'attention': [],
#  'film': [],
#  'Republican': [],
#  'tree': [],
#  'source': [],
#  'organization': [],
#  'hair': ['linja'],
#  'look': ['lukin'],
#  'century': [],
#  'evidence': [],
#  'window': ['lupa'],
#  'culture': [],
#  'chance': ['kama'],
#  'brother': ['pata'],
#  'energy': ['pika', 'wawa'],
#  'period': [],
#  'course': [],
#  'summer': [],
#  'plant': ['kasi'],
#  'opportunity': [],
#  'term': [],
#  'letter': [],
#  'condition': [],
#  'choice': [],
#  'rule': ['lawa'],
#  'daughter': [],
#  'administration': [],
#  'south': [],
#  'husband': ['mije'],
#  'Congress': [],
#  'floor': ['anpa', 'supa'],
#  'campaign': [],
#  'material': ['sijelo'],
#  'population': [],
#  'call': [],
#  'economy': [],
#  'hospital': [],
#  'church': [],
#  'risk': [],
#  'fire': ['seli'],
#  'future': ['kama'],
#  'defense': [],
#  'security': [],
#  'bank': [],
#  'west': [],
#  'sport': [],
#  'board': [],
#  'subject': [],
#  'officer': [],
#  'rest': ['lape'],
#  'behavior': [],
#  'performance': [],
#  'top': ['sewi'],
#  'goal': [],
#  'second': [],
#  'bed': [],
#  'order': [],
#  'author': [],
#  'blood': [],
#  'agency': [],
#  'nature': [],
#  'color': ['kule'],
#  'store': [],
#  'sound': ['kalama'],
#  'movement': ['tawa'],
#  'page': [],
#  'race': [],
#  'concern': [],
#  'series': [],
#  'language': ['toki'],
#  'response': [],
#  'animal': ['soweli'],
#  'factor': [],
#  'decade': [],
#  'article': [],
#  'east': [],
#  'artist': [],
#  'scene': [],
#  'stock': [],
#  'career': [],
#  'treatment': [],
#  'approach': [],
#  'size': ['suli'],
#  'dog': [],
#  'fund': [],
#  'media': [],
#  'sign': [],
#  'thought': [],
#  'list': [],
#  'individual': [],
#  'quality': [],
#  'pressure': [],
#  'answer': [],
#  'resource': [],
#  'meeting': [],
#  'disease': [],
#  'success': [],
#  'cup': ['poki'],
#  'amount': ['mute'],
#  'ability': ['ken'],
#  'staff': [],
#  'character': [],
#  'growth': [],
#  'loss': [],
#  'degree': [],
#  'attack': ['utala'],
#  'region': [],
#  'television': [],
#  'box': ['poki'],
#  'TV': [],
#  'training': [],
#  'trade': ['esun'],
#  'deal': [],
#  'election': [],
#  'feeling': ['pilin'],
#  'standard': [],
#  'bill': [],
#  'message': [],
#  'analysis': [],
#  'benefit': [],
#  'sex': ['unpa'],
#  'lawyer': [],
#  'section': ['kipisi'],
#  'glass': ['poki'],
#  'skill': [],
#  'sister': [],
#  'professor': [],
#  'operation': [],
#  'crime': [],
#  'stage': [],
#  'authority': [],
#  'design': [],
#  'sort': [],
#  'one': ['wan'],
#  'knowledge': ['sona'],
#  'gun': [],
#  'station': [],
#  'strategy': [],
#  'truth': [],
#  'song': [],
#  'example': [],
#  'environment': [],
#  'leg': ['noka'],
#  'public': ['kulupu'],
#  'executive': [],
#  'set': [],
#  'rock': ['kiwen'],
#  'note': [],
#  'manager': [],
#  'help': [],
#  'network': ['soko'],
#  'science': [],
#  'memory': [],
#  'card': ['lipu'],
#  'seat': [],
#  'cell': [],
#  'trial': [],
#  'expert': [],
#  'spring': [],
#  'firm': [],
#  'Democrat': [],
#  'radio': [],
#  'management': [],
#  'ball': ['sike'],
#  'talk': ['toki'],
#  'theory': ['nasara'],
#  'impact': [],
#  'statement': ['nimi'],
#  'charge': [],
#  'direction': [],
#  'weapon': [],
#  'employee': [],
#  'peace': [],
#  'base': [],
#  'pain': [],
#  'play': ['musi'],
#  'measure': [],
#  'interview': [],
#  'chair': ['supa'],
#  'fish': ['kala'],
#  'camera': [],
#  'structure': [],
#  'politics': [],
#  'bit': [],
#  'weight': [],
#  'candidate': [],
#  'production': [],
#  'trip': [],
#  'evening': [],
#  'conference': [],
#  'unit': ['wan'],
#  'style': [],
#  'adult': ['suli'],
#  'range': [],
#  'past': ['pini'],
#  'edge': [],
#  'writer': [],
#  'trouble': [],
#  'challenge': [],
#  'fear': ['monsuta'],
#  'shoulder': [],
#  'institution': [],
#  'sea': [],
#  'dream': [],
#  'bar': [],
#  'property': [],
#  'stuff': ['ijo'],
#  'detail': [],
#  'method': ['nasin'],
#  'magazine': [],
#  'hotel': [],
#  'soldier': [],
#  'cause': ['pana', 'tan'],
#  'bag': [],
#  'heat': ['seli'],
#  'fall': [],
#  'marriage': [],
#  'surface': [],
#  'purpose': ['waleja'],
#  'pattern': [],
#  'skin': ['selo'],
#  'agent': [],
#  'owner': [],
#  'machine': ['ilo'],
#  'gas': [],
#  'generation': [],
#  'cancer': [],
#  'item': [],
#  'reality': ['kin'],
#  'coach': [],
#  'Mrs': [],
#  'yard': [],
#  'violence': ['utala'],
#  'investment': [],
#  'discussion': [],
#  'finger': [],
#  'garden': [],
#  'collection': [],
#  'task': [],
#  'partner': [],
#  'kitchen': [],
#  'consumer': [],
#  'shot': [],
#  'budget': [],
#  'painting': [],
#  'scientist': [],
#  'agreement': ['amin'],
#  'capital': ['mani'],
#  'mouth': ['uta'],
#  'victim': [],
#  'newspaper': [],
#  'threat': [],
#  'responsibility': [],
#  'attorney': [],
#  'score': [],
#  'account': [],
#  'break': ['pakala'],
#  'audience': [],
#  'dinner': [],
#  'vote': [],
#  'debate': [],
#  'citizen': [],
#  'majority': [],
#  'wind': ['kon'],
#  'mission': [],
#  'customer': [],
#  'speech': ['toki'],
#  'option': [],
#  'participant': [],
#  'forest': [],
#  'video': [],
#  'Senate': [],
#  'reform': [],
#  'access': [],
#  'restaurant': [],
#  'judge': [],
#  'relation': [],
#  'bird': ['waso'],
#  'opinion': ['nasara'],
#  'credit': [],
#  'corner': [],
#  'version': [],
#  'safety': [],
#  'neighborhood': [],
#  'act': ['pali'],
#  'troop': [],
#  'income': [],
#  'species': [],
#  'track': [],
#  'hope': [],
#  'sky': ['naja'],
#  'freedom': [],
#  'plane': [],
#  'object': ['ijo'],
#  'attitude': [],
#  'labor': [],
#  'concept': [],
#  'client': [],
#  'conversation': [],
#  'variety': [],
#  'turn': [],
#  'investigation': [],
#  'researcher': [],
#  'press': [],
#  'conflict': ['utala'],
#  'spirit': [],
#  'argument': [],
#  'camp': [],
#  'brain': [],
#  'feature': [],
#  'afternoon': [],
#  'weekend': [],
#  'possibility': ['ken'],
#  'insurance': [],
#  'department': [],
#  'battle': ['utala'],
#  'beginning': ['kama', 'open'],
#  'date': [],
#  'crisis': [],
#  'fan': [],
#  'hole': ['lupa'],
#  'element': ['wan'],
#  'vision': ['lukin'],
#  'status': ['jeno'],
#  'ship': [],
#  'solution': [],
#  'stone': ['kiwen'],
#  'scale': [],
#  'university': [],
#  'driver': [],
#  'attempt': ['nasara'],
#  'park': [],
#  'spot': [],
#  'lack': [],
#  'ice': [],
#  'boat': [],
#  'sun': ['suno'],
#  'distance': [],
#  'wood': [],
#  'truck': [],
#  'return': [],
#  'mountain': ['nena'],
#  'survey': [],
#  'tradition': ['majuna'],
#  'winter': [],
#  'village': [],
#  'sales': [],
#  'communication': [],
#  'run': [],
#  'screen': [],
#  'resident': [],
#  'gold': [],
#  'club': [],
#  'farm': [],
#  'increase': [],
#  'middle': [],
#  'presence': ['lon'],
#  'district': [],
#  'shape': ['selo'],
#  'reader': [],
#  'Ms': [],
#  'contract': ['amin'],
#  'crowd': [],
#  'apartment': [],
#  'strength': ['wawa'],
#  'band': [],
#  'horse': [],
#  'target': [],
#  'prison': [],
#  'guard': ['kosan', 'selo'],
#  'demand': [],
#  'reporter': [],
#  'text': [],
#  'share': [],
#  'tool': ['ilo', 'kepen'],
#  'vehicle': [],
#  'flight': [],
#  'facility': [],
#  'understanding': ['sona'],
#  'advantage': [],
#  'leadership': [],
#  'pound': [],
#  'basis': [],
#  'guest': [],
#  'sample': [],
#  'block': ['leko'],
#  'protection': [],
#  'while': [],
#  'identity': ['sama'],
#  'title': [],
#  'lesson': [],
#  'faith': [],
#  'river': [],
#  'living': [],
#  'technique': [],
#  'path': ['nasin'],
#  'ear': ['kute'],
#  'shop': ['esun'],
#  'folk': [],
#  'principle': [],
#  'border': [],
#  'competition': [],
#  'claim': [],
#  'equipment': [],
#  'critic': [],
#  'aspect': [],
#  'failure': [],
#  'Christmas': [],
#  'comment': [],
#  'affair': [],
#  'procedure': [],
#  'chairman': [],
#  'baseball': [],
#  'egg': [],
#  'belief': [],
#  'murder': [],
#  'gift': [],
#  'religion': [],
#  'review': [],
#  'editor': [],
#  'coffee': ['asite'],
#  'document': [],
#  'speed': [],
#  'influence': [],
#  'youth': ['lili'],
#  'wave': [],
#  'move': ['tawa'],
#  'quarter': [],
#  'background': ['waleja'],
#  'reaction': [],
#  'suit': [],
#  'perspective': [],
#  'construction': [],
#  'intelligence': ['sona'],
#  'connection': [],
#  'shoe': [],
#  'grade': [],
#  'context': ['waleja'],
#  'committee': [],
#  'mistake': ['pakala'],
#  'focus': [],
#  'smile': [],
#  'location': [],
#  'clothes': [],
#  'neighbor': [],
#  'drive': [],
#  'function': ['pali'],
#  'bone': [],
#  'average': ['meso'],
#  'wine': [],
#  'voter': [],
#  'mean': [],
#  'learning': [],
#  'bus': [],
#  'hell': [],
#  'category': [],
#  'victory': [],
#  'key': [],
#  'visit': ['tawa'],
#  'Internet': [],
#  'medicine': [],
#  'tour': [],
#  'photo': [],
#  'finding': [],
#  'classroom': [],
#  'contact': [],
#  'justice': [],
#  'pair': ['tu'],
#  'exercise': [],
#  'knee': [],
#  'flower': [],
#  'tape': [],
#  'supply': [],
#  'cut': ['kipisi'],
#  'will': ['wile'],
#  'actor': [],
#  'birth': [],
#  'search': ['alasa'],
#  'democracy': [],
#  'circle': ['sike'],
#  'device': ['ilo'],
#  'progress': [],
#  'front': ['sinpin'],
#  'bottom': ['anpa', 'noka'],
#  'island': [],
#  'exchange': ['pana'],
#  'studio': [],
#  'lady': [],
#  'colleague': [],
#  'application': [],
#  'neck': [],
#  'damage': ['pakala'],
#  'plastic': ['kemu'],
#  'plate': [],
#  'writing': ['sitelen'],
#  'start': ['open'],
#  'expression': [],
#  'football': [],
#  'chicken': [],
#  'army': [],
#  'abuse': [],
#  'theater': [],
#  'map': [],
#  'session': [],
#  'danger': [],
#  'literature': [],
#  'rain': [],
#  'desire': ['wile'],
#  'assessment': [],
#  'injury': [],
#  'respect': ['olin'],
#  'fuel': [],
#  'leaf': ['kasi'],
#  'instruction': [],
#  'fight': ['utala'],
#  'pool': [],
#  'lead': ['lawa'],
#  'engine': [],
#  'salt': ['namako'],
#  'importance': [],
#  'metal': ['kiwen'],
#  'fat': [],
#  'ticket': ['lipu'],
#  'software': [],
#  'lip': [],
#  'reading': [],
#  'lunch': [],
#  'farmer': [],
#  'sugar': ['namako'],
#  'planet': [],
#  'enemy': [],
#  'athlete': [],
#  'soul': ['kon'],
#  'panel': [],
#  'meaning': [],
#  'mom': [],
#  'instrument': [],
#  'weather': [],
#  'commitment': [],
#  'pocket': [],
#  'temperature': [],
#  'surprise': [],
#  'poll': [],
#  'proposal': [],
#  'consequence': [],
#  'half': [],
#  'breath': [],
#  'sight': ['lukin'],
#  'cover': [],
#  'balance': [],
#  'minority': [],
#  'works': [],
#  'teaching': [],
#  'aid': [],
#  'advice': [],
#  'photograph': [],
#  'trail': [],
#  'novel': [],
#  'code': [],
#  'jury': [],
#  'breast': [],
#  'human': ['jan'],
#  'theme': [],
#  'storm': [],
#  'union': ['en'],
#  'desk': [],
#  'thanks': [],
#  'fruit': ['kili'],
#  'conclusion': [],
#  'shadow': [],
#  'analyst': [],
#  'dance': [],
#  'limit': [],
#  'regulation': [],
#  'being': ['jan', 'lon'],
#  'ring': ['kalama'],
#  'revenue': [],
#  'county': [],
#  'appearance': [],
#  'package': [],
#  'difficulty': [],
#  'bridge': [],
#  'train': [],
#  'e-mail': [],
#  'thinking': [],
#  'trend': [],
#  'visitor': [],
#  'loan': ['amin'],
#  'investor': [],
#  'profit': [],
#  'crew': [],
#  'accident': ['pakala'],
#  'male': ['mije'],
#  'meal': ['moku'],
#  'hearing': ['kute'],
#  'traffic': [],
#  'muscle': [],
#  'notion': [],
#  'earth': ['ma'],
#  'chest': ['sinpin'],
#  'cash': [],
#  'museum': [],
#  'beauty': [],
#  'emergency': [],
#  'stress': [],
#  'content': ['jo'],
#  'root': [],
#  'nose': ['nena'],
#  'bottle': ['poki'],
#  'setting': [],
#  'dress': ['len'],
#  'file': [],
#  'outcome': [],
#  'ad': [],
#  'duty': [],
#  'sheet': ['lipu'],
#  'extent': [],
#  'component': [],
#  'contrast': [],
#  'zone': [],
#  'airport': [],
#  'chief': [],
#  'shirt': [],
#  'pilot': [],
#  'cat': [],
#  'contribution': [],
#  'capacity': [],
#  'estate': [],
#  'guide': [],
#  'circumstance': [],
#  'snow': [],
#  'politician': [],
#  'percentage': [],
#  'meat': [],
#  'soil': [],
#  'surgery': [],
#  'basketball': [],
#  'golf': [],
#  'chain': ['linja'],
#  'address': [],
#  'branch': [],
#  'combination': [],
#  'governor': [],
#  'relief': [],
#  'user': [],
#  'dad': [],
#  'manner': ['nasin'],
#  'silence': [],
#  'rating': [],
#  'motion': [],
#  'gender': [],
#  'fee': [],
#  'landscape': [],
#  'bowl': ['poki'],
#  'frame': [],
#  'host': [],
#  'hall': [],
#  'ocean': [],
#  'row': [],
#  'producer': [],
#  'regime': [],
#  'division': [],
#  'appeal': [],
#  'mirror': [],
#  'tooth': [],
#  'length': ['enko'],
#  'topic': [],
#  'variable': [],
#  'telephone': [],
#  'perception': [],
#  'confidence': [],
#  'bedroom': [],
#  'secret': [],
#  'debt': [],
#  'tank': [],
#  'nurse': [],
#  'coverage': [],
#  'opposition': [],
#  'bond': [],
#  'pleasure': [],
#  'master': [],
#  'era': [],
#  'requirement': [],
#  'check': [],
#  'stand': [],
#  'fun': ['musi'],
#  'expectation': [],
#  'wing': [],
#  'struggle': [],
#  'judgment': [],
#  'beer': [],
#  'English': [],
#  'reference': [],
#  'tear': [],
#  'doubt': [],
#  'minister': [],
#  'hero': [],
#  'cloud': [],
#  'winner': [],
#  'volume': ['enko'],
#  'travel': ['ekon', 'tawa'],
#  'seed': [],
#  'fashion': [],
#  'pepper': [],
#  'intervention': [],
#  'copy': [],
#  'tip': ['pini'],
#  'welfare': [],
#  'vegetable': ['kasi', 'kili'],
#  'dish': [],
#  'beach': [],
#  'improvement': [],
#  'opening': ['open'],
#  'route': [],
#  'league': [],
#  'core': [],
#  'rise': [],
#  'tie': [],
#  'holiday': [],
#  'resolution': [],
#  'household': ['tomo'],
#  'abortion': [],
#  'witness': [],
#  'sector': [],
#  'representative': [],
#  'black': ['pimeja'],
#  'incident': [],
#  'flow': [],
#  'faculty': [],
#  'waste': [],
#  'mass': [],
#  'experiment': [],
#  'bomb': [],
#  'tone': [],
#  'engineer': ['tomo'],
#  'wheel': [],
#  'female': ['meli'],
#  'promise': [],
#  'cable': [],
#  'AIDS': [],
#  'Jew': [],
#  'cream': [],
#  'secretary': [],
#  'gate': [],
#  'hill': ['nena'],
#  'noise': ['kalama'],
#  'grass': [],
#  'hat': [],
#  'legislation': [],
#  'achievement': [],
#  'fishing': [],
#  'drink': ['moku'],
#  'talent': [],
#  'taste': [],
#  'characteristic': [],
#  'milk': [],
#  'sentence': [],
#  'height': [],
#  'physician': [],
#  'sleep': ['lape'],
#  'ride': [],
#  'explanation': [],
#  'campus': [],
#  'potential': [],
#  'immigrant': [],
#  'alternative': [],
#  'interaction': [],
#  'column': [],
#  'personality': [],
#  'signal': [],
#  'curriculum': [],
#  'honor': [],
#  'passenger': [],
#  'assistance': [],
#  'association': [],
#  'lab': [],
#  'offer': [],
#  'criticism': [],
#  'asset': [],
#  'depression': [],
#  'journalist': [],
#  'prayer': [],
#  'scholar': [],
#  'warning': [],
#  'climate': [],
#  'cheese': [],
#  'observation': [],
#  'childhood': [],
#  'payment': [],
#  'sir': [],
#  'cigarette': [],
#  'definition': [],
#  'priority': [],
#  'bread': [],
#  'creation': [],
#  'graduate': [],
#  'request': [],
#  'emotion': ['pilin'],
#  ...}

# %%
f = pd.merge(hypernyms,hyponyms)
f
# Out:
#                 lemma  Count part_of_speech                   hypernyms  \
# 0                0.22      4           noun                     firearm
# 1                   1      1           noun                       digit
# 2                   2      1           noun                       digit
# 3                  12      2           noun               large integer
# 4                1000      4           noun               large integer
# ...               ...    ...            ...                         ...
# 33611  zoroastrianism     14           noun                    religion
# 33612          zoysia      6           noun                       grass
# 33613          zygote      6           noun                        cell
# 33614       zymolysis      9           noun            chemical process
# 33615         zymosis      7           noun  chemical process|infection
#
#                                                 hyponyms
# 0                     twenty-two pistol;twenty-two rifle
# 1                                        monad;singleton
# 2                                           couple;craps
# 3                                                boxcars
# 4                                              millenary
# ...                                                  ...
# 33611                                           parsiism
# 33612     korean lawn grass;manila grass;mascarene grass
# 33613                            heterozygote;homozygote
# 33614  bottom fermentation;top fermentation;vinification
# 33615  bottom fermentation;top fermentation;vinificat...
#
# [33616 rows x 5 columns]

# %%
ok = set(nouns + verbs + adjcs + advbs)
defs  = dict([(x,y) for x,y in zip(list(noundefs.Word), list(noundefs.Definition))])
defsV = dict([(x,y) for x,y in zip(list(verbdefs.Word), list(verbdefs.Definition))])
defsA = dict([(x,y) for x,y in zip(list(adjcdefs.Word), list(adjcdefs.Definition))])
defs.update(defsV)
defs.update(defsA)
tok2eng_level_2 = tok2eng_level_1
for k in tok2eng_level_1:
    if tok2eng_level_1[k] == '':
        if k in synonyms:
            syns = synonyms[k]
            for c in f[f.lemma == k]:
                syns += str(c['hypernyms']).split('|')
                syns += str(c['hyponyms']).split(';')
            for s in syns:
                if s in edict:
                    tok2eng_level_2[k] += (f'{edict[s]}')
                if s in defs:
                    defn = defs[s]
                    for word in defn.split():
                        if word in edict and word in ok:
                            tok2eng_level_2[k] += (f'{edict[word]}')
        if k in defs:
            defn = defs[k]
            for word in defn.split():
                if word in edict and word in ok:
                    tok2eng_level_2[k] += (f'{edict[word]}')
# c=1
# for i in tok2eng_level_2.keys():
#     if tok2eng_level_2[i] != []:
#         print(c, i, tok2eng_level_2[i])
#         c+=1
tok2eng_level_2
# Out:
# {'time': ['tenpo'],
#  'year': [],
#  'people': ['jan', 'kulupu'],
#  'way': ['nasin'],
#  'day': [],
#  'man': ['mije'],
#  'thing': ['ijo'],
#  'woman': ['meli'],
#  'life': ['konwe'],
#  'child': [],
#  'world': [],
#  'school': [],
#  'state': [],
#  'family': [],
#  'student': [],
#  'group': ['kulupu'],
#  'country': ['ma'],
#  'problem': [],
#  'hand': ['luka'],
#  'part': ['ipa'],
#  'place': ['jeno'],
#  'case': [],
#  'week': [],
#  'company': ['kulupu'],
#  'system': ['nasin'],
#  'program': [],
#  'question': [],
#  'work': ['pali'],
#  'government': [],
#  'number': ['nanpa'],
#  'night': [],
#  'Mr': [],
#  'point': [],
#  'home': ['tomo'],
#  'water': ['telo'],
#  'room': ['tomo'],
#  'mother': ['mama'],
#  'area': [],
#  'money': ['mani'],
#  'story': [],
#  'fact': ['kin'],
#  'month': [],
#  'lot': [],
#  'right': ['pona'],
#  'study': ['sona'],
#  'book': ['lipu'],
#  'eye': ['oko'],
#  'job': [],
#  'word': ['nimi'],
#  'business': ['esun'],
#  'issue': [],
#  'side': ['poka'],
#  'kind': [],
#  'head': ['lawa'],
#  'house': [],
#  'service': [],
#  'friend': [],
#  'father': ['mama'],
#  'power': ['wawa'],
#  'hour': [],
#  'game': ['musi'],
#  'line': ['linja'],
#  'end': ['pake', 'pini'],
#  'member': [],
#  'law': [],
#  'car': [],
#  'city': [],
#  'community': ['kulupu'],
#  'name': ['nimi'],
#  'president': [],
#  'team': [],
#  'minute': [],
#  'idea': [],
#  'kid': [],
#  'body': [],
#  'information': [],
#  'back': ['monsi'],
#  'parent': ['mama'],
#  'face': ['sinpin'],
#  'others': [],
#  'level': ['jeno'],
#  'office': [],
#  'door': ['lupa'],
#  'health': [],
#  'person': ['jan'],
#  'art': ['musi'],
#  'war': ['utala'],
#  'history': [],
#  'party': [],
#  'result': [],
#  'change': ['ante'],
#  'morning': [],
#  'reason': ['waleja'],
#  'research': [],
#  'girl': ['meli'],
#  'guy': [],
#  'food': ['moku'],
#  'moment': ['tenpo'],
#  'air': ['kon'],
#  'teacher': [],
#  'force': [],
#  'education': [],
#  'foot': [],
#  'boy': [],
#  'age': [],
#  'policy': [],
#  'process': [],
#  'music': [],
#  'market': ['esun'],
#  'sense': ['pilin'],
#  'nation': [],
#  'plan': [],
#  'college': [],
#  'interest': [],
#  'death': ['moli'],
#  'experience': [],
#  'effect': [],
#  'use': ['kepen'],
#  'class': [],
#  'control': ['lawa'],
#  'care': [],
#  'field': [],
#  'development': [],
#  'role': [],
#  'effort': [],
#  'rate': [],
#  'heart': [],
#  'drug': [],
#  'show': [],
#  'leader': [],
#  'light': ['pika', 'suno'],
#  'voice': ['kalama'],
#  'wife': ['meli'],
#  'police': [],
#  'mind': ['lawa'],
#  'price': [],
#  'report': [],
#  'decision': [],
#  'son': [],
#  'view': ['lukin'],
#  'relationship': [],
#  'town': [],
#  'road': ['nasin'],
#  'arm': ['luka'],
#  'difference': ['ante'],
#  'value': [],
#  'building': ['tomo'],
#  'action': [],
#  'model': [],
#  'season': [],
#  'society': ['kulupu'],
#  'tax': [],
#  'director': [],
#  'position': ['jeno'],
#  'player': [],
#  'record': [],
#  'paper': ['lipu'],
#  'space': ['naja'],
#  'ground': [],
#  'form': [],
#  'event': ['kama'],
#  'official': [],
#  'matter': [],
#  'center': [],
#  'couple': [],
#  'site': [],
#  'project': ['pali'],
#  'activity': ['pali'],
#  'star': ['mun'],
#  'table': ['supa'],
#  'need': ['wile'],
#  'court': [],
#  'American': [],
#  'oil': ['ojele'],
#  'situation': ['tenpo'],
#  'cost': [],
#  'industry': [],
#  'figure': [],
#  'street': [],
#  'image': ['sitelen'],
#  'phone': [],
#  'data': [],
#  'picture': ['sitelen'],
#  'practice': [],
#  'piece': [],
#  'land': ['ma'],
#  'product': [],
#  'doctor': [],
#  'wall': ['sinpin'],
#  'patient': [],
#  'worker': [],
#  'news': ['sin'],
#  'test': [],
#  'movie': [],
#  'north': [],
#  'love': ['olin'],
#  'support': [],
#  'technology': [],
#  'step': [],
#  'baby': [],
#  'computer': [],
#  'type': [],
#  'attention': [],
#  'film': [],
#  'Republican': [],
#  'tree': [],
#  'source': [],
#  'organization': [],
#  'hair': ['linja'],
#  'look': ['lukin'],
#  'century': [],
#  'evidence': [],
#  'window': ['lupa'],
#  'culture': [],
#  'chance': ['kama'],
#  'brother': ['pata'],
#  'energy': ['pika', 'wawa'],
#  'period': [],
#  'course': [],
#  'summer': [],
#  'plant': ['kasi'],
#  'opportunity': [],
#  'term': [],
#  'letter': [],
#  'condition': [],
#  'choice': [],
#  'rule': ['lawa'],
#  'daughter': [],
#  'administration': [],
#  'south': [],
#  'husband': ['mije'],
#  'Congress': [],
#  'floor': ['anpa', 'supa'],
#  'campaign': [],
#  'material': ['sijelo'],
#  'population': [],
#  'call': [],
#  'economy': [],
#  'hospital': [],
#  'church': [],
#  'risk': [],
#  'fire': ['seli'],
#  'future': ['kama'],
#  'defense': [],
#  'security': [],
#  'bank': [],
#  'west': [],
#  'sport': [],
#  'board': [],
#  'subject': [],
#  'officer': [],
#  'rest': ['lape'],
#  'behavior': [],
#  'performance': [],
#  'top': ['sewi'],
#  'goal': [],
#  'second': [],
#  'bed': [],
#  'order': [],
#  'author': [],
#  'blood': [],
#  'agency': [],
#  'nature': [],
#  'color': ['kule'],
#  'store': [],
#  'sound': ['kalama'],
#  'movement': ['tawa'],
#  'page': [],
#  'race': [],
#  'concern': [],
#  'series': [],
#  'language': ['toki'],
#  'response': [],
#  'animal': ['soweli'],
#  'factor': [],
#  'decade': [],
#  'article': [],
#  'east': [],
#  'artist': [],
#  'scene': [],
#  'stock': [],
#  'career': [],
#  'treatment': [],
#  'approach': [],
#  'size': ['suli'],
#  'dog': [],
#  'fund': [],
#  'media': [],
#  'sign': [],
#  'thought': [],
#  'list': [],
#  'individual': [],
#  'quality': [],
#  'pressure': [],
#  'answer': [],
#  'resource': [],
#  'meeting': [],
#  'disease': [],
#  'success': [],
#  'cup': ['poki'],
#  'amount': ['mute'],
#  'ability': ['ken'],
#  'staff': [],
#  'character': [],
#  'growth': [],
#  'loss': [],
#  'degree': [],
#  'attack': ['utala'],
#  'region': [],
#  'television': [],
#  'box': ['poki'],
#  'TV': [],
#  'training': [],
#  'trade': ['esun'],
#  'deal': [],
#  'election': [],
#  'feeling': ['pilin'],
#  'standard': [],
#  'bill': [],
#  'message': [],
#  'analysis': [],
#  'benefit': [],
#  'sex': ['unpa'],
#  'lawyer': [],
#  'section': ['kipisi'],
#  'glass': ['poki'],
#  'skill': [],
#  'sister': [],
#  'professor': [],
#  'operation': [],
#  'crime': [],
#  'stage': [],
#  'authority': [],
#  'design': [],
#  'sort': [],
#  'one': ['wan'],
#  'knowledge': ['sona'],
#  'gun': [],
#  'station': [],
#  'strategy': [],
#  'truth': [],
#  'song': [],
#  'example': [],
#  'environment': [],
#  'leg': ['noka'],
#  'public': ['kulupu'],
#  'executive': [],
#  'set': [],
#  'rock': ['kiwen'],
#  'note': [],
#  'manager': [],
#  'help': [],
#  'network': ['soko'],
#  'science': [],
#  'memory': [],
#  'card': ['lipu'],
#  'seat': [],
#  'cell': [],
#  'trial': [],
#  'expert': [],
#  'spring': [],
#  'firm': [],
#  'Democrat': [],
#  'radio': [],
#  'management': [],
#  'ball': ['sike'],
#  'talk': ['toki'],
#  'theory': ['nasara'],
#  'impact': [],
#  'statement': ['nimi'],
#  'charge': [],
#  'direction': [],
#  'weapon': [],
#  'employee': [],
#  'peace': [],
#  'base': [],
#  'pain': [],
#  'play': ['musi'],
#  'measure': [],
#  'interview': [],
#  'chair': ['supa'],
#  'fish': ['kala'],
#  'camera': [],
#  'structure': [],
#  'politics': [],
#  'bit': [],
#  'weight': [],
#  'candidate': [],
#  'production': [],
#  'trip': [],
#  'evening': [],
#  'conference': [],
#  'unit': ['wan'],
#  'style': [],
#  'adult': ['suli'],
#  'range': [],
#  'past': ['pini'],
#  'edge': [],
#  'writer': [],
#  'trouble': [],
#  'challenge': [],
#  'fear': ['monsuta'],
#  'shoulder': [],
#  'institution': [],
#  'sea': [],
#  'dream': [],
#  'bar': [],
#  'property': [],
#  'stuff': ['ijo'],
#  'detail': [],
#  'method': ['nasin'],
#  'magazine': [],
#  'hotel': [],
#  'soldier': [],
#  'cause': ['pana', 'tan'],
#  'bag': [],
#  'heat': ['seli'],
#  'fall': [],
#  'marriage': [],
#  'surface': [],
#  'purpose': ['waleja'],
#  'pattern': [],
#  'skin': ['selo'],
#  'agent': [],
#  'owner': [],
#  'machine': ['ilo'],
#  'gas': [],
#  'generation': [],
#  'cancer': [],
#  'item': [],
#  'reality': ['kin'],
#  'coach': [],
#  'Mrs': [],
#  'yard': [],
#  'violence': ['utala'],
#  'investment': [],
#  'discussion': [],
#  'finger': [],
#  'garden': [],
#  'collection': [],
#  'task': [],
#  'partner': [],
#  'kitchen': [],
#  'consumer': [],
#  'shot': [],
#  'budget': [],
#  'painting': [],
#  'scientist': [],
#  'agreement': ['amin'],
#  'capital': ['mani'],
#  'mouth': ['uta'],
#  'victim': [],
#  'newspaper': [],
#  'threat': [],
#  'responsibility': [],
#  'attorney': [],
#  'score': [],
#  'account': [],
#  'break': ['pakala'],
#  'audience': [],
#  'dinner': [],
#  'vote': [],
#  'debate': [],
#  'citizen': [],
#  'majority': [],
#  'wind': ['kon'],
#  'mission': [],
#  'customer': [],
#  'speech': ['toki'],
#  'option': [],
#  'participant': [],
#  'forest': [],
#  'video': [],
#  'Senate': [],
#  'reform': [],
#  'access': [],
#  'restaurant': [],
#  'judge': [],
#  'relation': [],
#  'bird': ['waso'],
#  'opinion': ['nasara'],
#  'credit': [],
#  'corner': [],
#  'version': [],
#  'safety': [],
#  'neighborhood': [],
#  'act': ['pali'],
#  'troop': [],
#  'income': [],
#  'species': [],
#  'track': [],
#  'hope': [],
#  'sky': ['naja'],
#  'freedom': [],
#  'plane': [],
#  'object': ['ijo'],
#  'attitude': [],
#  'labor': [],
#  'concept': [],
#  'client': [],
#  'conversation': [],
#  'variety': [],
#  'turn': [],
#  'investigation': [],
#  'researcher': [],
#  'press': [],
#  'conflict': ['utala'],
#  'spirit': [],
#  'argument': [],
#  'camp': [],
#  'brain': [],
#  'feature': [],
#  'afternoon': [],
#  'weekend': [],
#  'possibility': ['ken'],
#  'insurance': [],
#  'department': [],
#  'battle': ['utala'],
#  'beginning': ['kama', 'open'],
#  'date': [],
#  'crisis': [],
#  'fan': [],
#  'hole': ['lupa'],
#  'element': ['wan'],
#  'vision': ['lukin'],
#  'status': ['jeno'],
#  'ship': [],
#  'solution': [],
#  'stone': ['kiwen'],
#  'scale': [],
#  'university': [],
#  'driver': [],
#  'attempt': ['nasara'],
#  'park': [],
#  'spot': [],
#  'lack': [],
#  'ice': [],
#  'boat': [],
#  'sun': ['suno'],
#  'distance': [],
#  'wood': [],
#  'truck': [],
#  'return': [],
#  'mountain': ['nena'],
#  'survey': [],
#  'tradition': ['majuna'],
#  'winter': [],
#  'village': [],
#  'sales': [],
#  'communication': [],
#  'run': [],
#  'screen': [],
#  'resident': [],
#  'gold': [],
#  'club': [],
#  'farm': [],
#  'increase': [],
#  'middle': [],
#  'presence': ['lon'],
#  'district': [],
#  'shape': ['selo'],
#  'reader': [],
#  'Ms': [],
#  'contract': ['amin'],
#  'crowd': [],
#  'apartment': [],
#  'strength': ['wawa'],
#  'band': [],
#  'horse': [],
#  'target': [],
#  'prison': [],
#  'guard': ['kosan', 'selo'],
#  'demand': [],
#  'reporter': [],
#  'text': [],
#  'share': [],
#  'tool': ['ilo', 'kepen'],
#  'vehicle': [],
#  'flight': [],
#  'facility': [],
#  'understanding': ['sona'],
#  'advantage': [],
#  'leadership': [],
#  'pound': [],
#  'basis': [],
#  'guest': [],
#  'sample': [],
#  'block': ['leko'],
#  'protection': [],
#  'while': [],
#  'identity': ['sama'],
#  'title': [],
#  'lesson': [],
#  'faith': [],
#  'river': [],
#  'living': [],
#  'technique': [],
#  'path': ['nasin'],
#  'ear': ['kute'],
#  'shop': ['esun'],
#  'folk': [],
#  'principle': [],
#  'border': [],
#  'competition': [],
#  'claim': [],
#  'equipment': [],
#  'critic': [],
#  'aspect': [],
#  'failure': [],
#  'Christmas': [],
#  'comment': [],
#  'affair': [],
#  'procedure': [],
#  'chairman': [],
#  'baseball': [],
#  'egg': [],
#  'belief': [],
#  'murder': [],
#  'gift': [],
#  'religion': [],
#  'review': [],
#  'editor': [],
#  'coffee': ['asite'],
#  'document': [],
#  'speed': [],
#  'influence': [],
#  'youth': ['lili'],
#  'wave': [],
#  'move': ['tawa'],
#  'quarter': [],
#  'background': ['waleja'],
#  'reaction': [],
#  'suit': [],
#  'perspective': [],
#  'construction': [],
#  'intelligence': ['sona'],
#  'connection': [],
#  'shoe': [],
#  'grade': [],
#  'context': ['waleja'],
#  'committee': [],
#  'mistake': ['pakala'],
#  'focus': [],
#  'smile': [],
#  'location': [],
#  'clothes': [],
#  'neighbor': [],
#  'drive': [],
#  'function': ['pali'],
#  'bone': [],
#  'average': ['meso'],
#  'wine': [],
#  'voter': [],
#  'mean': [],
#  'learning': [],
#  'bus': [],
#  'hell': [],
#  'category': [],
#  'victory': [],
#  'key': [],
#  'visit': ['tawa'],
#  'Internet': [],
#  'medicine': [],
#  'tour': [],
#  'photo': [],
#  'finding': [],
#  'classroom': [],
#  'contact': [],
#  'justice': [],
#  'pair': ['tu'],
#  'exercise': [],
#  'knee': [],
#  'flower': [],
#  'tape': [],
#  'supply': [],
#  'cut': ['kipisi'],
#  'will': ['wile'],
#  'actor': [],
#  'birth': [],
#  'search': ['alasa'],
#  'democracy': [],
#  'circle': ['sike'],
#  'device': ['ilo'],
#  'progress': [],
#  'front': ['sinpin'],
#  'bottom': ['anpa', 'noka'],
#  'island': [],
#  'exchange': ['pana'],
#  'studio': [],
#  'lady': [],
#  'colleague': [],
#  'application': [],
#  'neck': [],
#  'damage': ['pakala'],
#  'plastic': ['kemu'],
#  'plate': [],
#  'writing': ['sitelen'],
#  'start': ['open'],
#  'expression': [],
#  'football': [],
#  'chicken': [],
#  'army': [],
#  'abuse': [],
#  'theater': [],
#  'map': [],
#  'session': [],
#  'danger': [],
#  'literature': [],
#  'rain': [],
#  'desire': ['wile'],
#  'assessment': [],
#  'injury': [],
#  'respect': ['olin'],
#  'fuel': [],
#  'leaf': ['kasi'],
#  'instruction': [],
#  'fight': ['utala'],
#  'pool': [],
#  'lead': ['lawa'],
#  'engine': [],
#  'salt': ['namako'],
#  'importance': [],
#  'metal': ['kiwen'],
#  'fat': [],
#  'ticket': ['lipu'],
#  'software': [],
#  'lip': [],
#  'reading': [],
#  'lunch': [],
#  'farmer': [],
#  'sugar': ['namako'],
#  'planet': [],
#  'enemy': [],
#  'athlete': [],
#  'soul': ['kon'],
#  'panel': [],
#  'meaning': [],
#  'mom': [],
#  'instrument': [],
#  'weather': [],
#  'commitment': [],
#  'pocket': [],
#  'temperature': [],
#  'surprise': [],
#  'poll': [],
#  'proposal': [],
#  'consequence': [],
#  'half': [],
#  'breath': [],
#  'sight': ['lukin'],
#  'cover': [],
#  'balance': [],
#  'minority': [],
#  'works': [],
#  'teaching': [],
#  'aid': [],
#  'advice': [],
#  'photograph': [],
#  'trail': [],
#  'novel': [],
#  'code': [],
#  'jury': [],
#  'breast': [],
#  'human': ['jan'],
#  'theme': [],
#  'storm': [],
#  'union': ['en'],
#  'desk': [],
#  'thanks': [],
#  'fruit': ['kili'],
#  'conclusion': [],
#  'shadow': [],
#  'analyst': [],
#  'dance': [],
#  'limit': [],
#  'regulation': [],
#  'being': ['jan', 'lon'],
#  'ring': ['kalama'],
#  'revenue': [],
#  'county': [],
#  'appearance': [],
#  'package': [],
#  'difficulty': [],
#  'bridge': [],
#  'train': [],
#  'e-mail': [],
#  'thinking': [],
#  'trend': [],
#  'visitor': [],
#  'loan': ['amin'],
#  'investor': [],
#  'profit': [],
#  'crew': [],
#  'accident': ['pakala'],
#  'male': ['mije'],
#  'meal': ['moku'],
#  'hearing': ['kute'],
#  'traffic': [],
#  'muscle': [],
#  'notion': [],
#  'earth': ['ma'],
#  'chest': ['sinpin'],
#  'cash': [],
#  'museum': [],
#  'beauty': [],
#  'emergency': [],
#  'stress': [],
#  'content': ['jo'],
#  'root': [],
#  'nose': ['nena'],
#  'bottle': ['poki'],
#  'setting': [],
#  'dress': ['len'],
#  'file': [],
#  'outcome': [],
#  'ad': [],
#  'duty': [],
#  'sheet': ['lipu'],
#  'extent': [],
#  'component': [],
#  'contrast': [],
#  'zone': [],
#  'airport': [],
#  'chief': [],
#  'shirt': [],
#  'pilot': [],
#  'cat': [],
#  'contribution': [],
#  'capacity': [],
#  'estate': [],
#  'guide': [],
#  'circumstance': [],
#  'snow': [],
#  'politician': [],
#  'percentage': [],
#  'meat': [],
#  'soil': [],
#  'surgery': [],
#  'basketball': [],
#  'golf': [],
#  'chain': ['linja'],
#  'address': [],
#  'branch': [],
#  'combination': [],
#  'governor': [],
#  'relief': [],
#  'user': [],
#  'dad': [],
#  'manner': ['nasin'],
#  'silence': [],
#  'rating': [],
#  'motion': [],
#  'gender': [],
#  'fee': [],
#  'landscape': [],
#  'bowl': ['poki'],
#  'frame': [],
#  'host': [],
#  'hall': [],
#  'ocean': [],
#  'row': [],
#  'producer': [],
#  'regime': [],
#  'division': [],
#  'appeal': [],
#  'mirror': [],
#  'tooth': [],
#  'length': ['enko'],
#  'topic': [],
#  'variable': [],
#  'telephone': [],
#  'perception': [],
#  'confidence': [],
#  'bedroom': [],
#  'secret': [],
#  'debt': [],
#  'tank': [],
#  'nurse': [],
#  'coverage': [],
#  'opposition': [],
#  'bond': [],
#  'pleasure': [],
#  'master': [],
#  'era': [],
#  'requirement': [],
#  'check': [],
#  'stand': [],
#  'fun': ['musi'],
#  'expectation': [],
#  'wing': [],
#  'struggle': [],
#  'judgment': [],
#  'beer': [],
#  'English': [],
#  'reference': [],
#  'tear': [],
#  'doubt': [],
#  'minister': [],
#  'hero': [],
#  'cloud': [],
#  'winner': [],
#  'volume': ['enko'],
#  'travel': ['ekon', 'tawa'],
#  'seed': [],
#  'fashion': [],
#  'pepper': [],
#  'intervention': [],
#  'copy': [],
#  'tip': ['pini'],
#  'welfare': [],
#  'vegetable': ['kasi', 'kili'],
#  'dish': [],
#  'beach': [],
#  'improvement': [],
#  'opening': ['open'],
#  'route': [],
#  'league': [],
#  'core': [],
#  'rise': [],
#  'tie': [],
#  'holiday': [],
#  'resolution': [],
#  'household': ['tomo'],
#  'abortion': [],
#  'witness': [],
#  'sector': [],
#  'representative': [],
#  'black': ['pimeja'],
#  'incident': [],
#  'flow': [],
#  'faculty': [],
#  'waste': [],
#  'mass': [],
#  'experiment': [],
#  'bomb': [],
#  'tone': [],
#  'engineer': ['tomo'],
#  'wheel': [],
#  'female': ['meli'],
#  'promise': [],
#  'cable': [],
#  'AIDS': [],
#  'Jew': [],
#  'cream': [],
#  'secretary': [],
#  'gate': [],
#  'hill': ['nena'],
#  'noise': ['kalama'],
#  'grass': [],
#  'hat': [],
#  'legislation': [],
#  'achievement': [],
#  'fishing': [],
#  'drink': ['moku'],
#  'talent': [],
#  'taste': [],
#  'characteristic': [],
#  'milk': [],
#  'sentence': [],
#  'height': [],
#  'physician': [],
#  'sleep': ['lape'],
#  'ride': [],
#  'explanation': [],
#  'campus': [],
#  'potential': [],
#  'immigrant': [],
#  'alternative': [],
#  'interaction': [],
#  'column': [],
#  'personality': [],
#  'signal': [],
#  'curriculum': [],
#  'honor': [],
#  'passenger': [],
#  'assistance': [],
#  'association': [],
#  'lab': [],
#  'offer': [],
#  'criticism': [],
#  'asset': [],
#  'depression': [],
#  'journalist': [],
#  'prayer': [],
#  'scholar': [],
#  'warning': [],
#  'climate': [],
#  'cheese': [],
#  'observation': [],
#  'childhood': [],
#  'payment': [],
#  'sir': [],
#  'cigarette': [],
#  'definition': [],
#  'priority': [],
#  'bread': [],
#  'creation': [],
#  'graduate': [],
#  'request': [],
#  'emotion': ['pilin'],
#  ...}

# %% [markdown]
# Underwhelming, expectedly. Our vectors have 300 dimensions, so we will need to do PCA on them.

# %%
word2vec = pd.read_csv("conceptnetw2v.csv")

# %%
list(word2vec[word2vec.word == 'bumpy'].to_numpy()[0][2:302])
# Out:
# [-0.0705,
#  -0.0289,
#  0.1469,
#  0.002,
#  0.0617,
#  -0.184,
#  -0.0325,
#  0.1357,
#  0.067,
#  0.0914,
#  -0.0949,
#  0.1012,
#  0.0309,
#  0.0633,
#  0.0749,
#  -0.0266,
#  -0.1353,
#  -0.0297,
#  0.1159,
#  0.0857,
#  0.0507,
#  0.0444,
#  0.0516,
#  -0.0854,
#  -0.0745,
#  0.0182,
#  0.0222,
#  0.0678,
#  -0.1286,
#  0.0112,
#  0.0311,
#  0.0422,
#  0.0061,
#  -0.0143,
#  -0.0041,
#  0.0953,
#  -0.0687,
#  0.0362,
#  0.0784,
#  -0.0192,
#  -0.0886,
#  0.0973,
#  0.0593,
#  0.0283,
#  -0.0267,
#  0.1029,
#  -0.118,
#  0.2267,
#  0.0763,
#  -0.0746,
#  -0.0068,
#  -0.0086,
#  0.1846,
#  -0.0283,
#  0.034,
#  0.0976,
#  -0.0696,
#  -0.0372,
#  -0.0394,
#  0.0799,
#  0.0451,
#  0.1086,
#  0.0545,
#  -0.0524,
#  -0.0805,
#  0.0261,
#  0.0395,
#  -0.062,
#  -0.0155,
#  -0.0583,
#  0.0968,
#  -0.0134,
#  0.0541,
#  0.0026,
#  -0.0712,
#  0.0533,
#  0.0226,
#  0.0289,
#  -0.0037,
#  -0.0513,
#  -0.0579,
#  -0.1049,
#  0.0327,
#  -0.0177,
#  -0.0161,
#  0.0042,
#  -0.0508,
#  -0.0538,
#  -0.1249,
#  0.018,
#  0.0212,
#  0.0003,
#  -0.094,
#  -0.0079,
#  -0.0417,
#  0.0409,
#  -0.1392,
#  0.1093,
#  0.055,
#  0.0393,
#  -0.0328,
#  0.0166,
#  0.0445,
#  -0.094,
#  0.022,
#  -0.0468,
#  -0.0289,
#  -0.0071,
#  0.0863,
#  -0.0225,
#  -0.0149,
#  -0.0298,
#  0.0662,
#  0.0479,
#  0.0972,
#  -0.0096,
#  -0.058,
#  -0.0122,
#  0.0401,
#  0.017,
#  -0.0455,
#  0.0245,
#  -0.0285,
#  -0.0597,
#  0.0682,
#  0.0315,
#  0.0595,
#  -0.0942,
#  -0.0421,
#  0.0006,
#  0.0342,
#  0.0442,
#  -0.0005,
#  0.1067,
#  0.022,
#  0.0753,
#  -0.0442,
#  0.0272,
#  -0.0279,
#  0.045,
#  0.0122,
#  -0.0204,
#  0.0161,
#  0.0903,
#  -0.0059,
#  0.015,
#  0.0239,
#  0.0171,
#  -0.0735,
#  -0.0809,
#  0.0377,
#  -0.0021,
#  0.034,
#  -0.0814,
#  -0.043,
#  0.084,
#  0.0182,
#  -0.0348,
#  0.1507,
#  0.0087,
#  0.0009,
#  -0.0846,
#  -0.0355,
#  0.0096,
#  -0.0108,
#  -0.0073,
#  0.0305,
#  0.0003,
#  -0.0731,
#  0.119,
#  -0.0836,
#  0.0744,
#  0.0074,
#  -0.0282,
#  -0.0053,
#  0.0657,
#  -0.0526,
#  0.0216,
#  0.0255,
#  -0.0635,
#  0.021,
#  0.0338,
#  0.0642,
#  0.0177,
#  -0.1066,
#  -0.015,
#  0.0347,
#  0.0022,
#  0.0038,
#  0.0006,
#  0.0014,
#  0.0292,
#  -0.0873,
#  0.069,
#  -0.0062,
#  -0.012,
#  0.0186,
#  0.0383,
#  -0.0165,
#  0.0299,
#  -0.013,
#  0.1178,
#  -0.0841,
#  -0.0412,
#  0.0113,
#  -0.0018,
#  0.0404,
#  0.0198,
#  0.0022,
#  -0.0208,
#  -0.0287,
#  0.0061,
#  -0.0289,
#  -0.0691,
#  0.0513,
#  -0.0594,
#  0.0121,
#  -0.057,
#  -0.0397,
#  0.0123,
#  0.0934,
#  -0.019,
#  -0.0181,
#  -0.0453,
#  0.0281,
#  0.0075,
#  -0.0389,
#  0.0074,
#  -0.0572,
#  -0.0487,
#  0.0347,
#  -0.0067,
#  -0.0459,
#  -0.0532,
#  0.0281,
#  0.0266,
#  0.0212,
#  -0.0923,
#  -0.0069,
#  0.0509,
#  -0.0453,
#  -0.019,
#  -0.0877,
#  -0.1265,
#  0.0178,
#  -0.0503,
#  -0.0505,
#  -0.0118,
#  -0.0469,
#  -0.0089,
#  -0.0513,
#  -0.0034,
#  0.0277,
#  0.0083,
#  -0.0553,
#  0.0344,
#  0.0724,
#  0.0084,
#  0.009,
#  0.0686,
#  0.0084,
#  -0.0365,
#  -0.0145,
#  -0.0121,
#  -0.0799,
#  0.0081,
#  0.0009,
#  -0.0331,
#  0.02,
#  -0.061,
#  -0.0127,
#  -0.0019,
#  -0.0321,
#  -0.014,
#  0.0125,
#  -0.0137,
#  0.097,
#  0.0326,
#  -0.01,
#  -0.0161,
#  0.0014,
#  0.0144,
#  0.0352,
#  0.0514,
#  -0.0616,
#  0.0952,
#  -0.0088,
#  0.0471,
#  0.012,
#  -0.0337,
#  0.0697,
#  -0.0132,
#  -0.028,
#  -0.0806,
#  -0.0123,
#  0.0288,
#  -0.012,
#  -0.0433,
#  -0.0108,
#  0.0093]

# %%
tpvecs = dict([(k, [0.0] * 300) for k in tokidict.keys()])
for k in tokidict.keys():
    denom = len(tokidict[k])
    for v in tokidict[k]:
        l = word2vec[word2vec.word == v].to_numpy()
        if len(l) > 0:
            tpvecs[k] += l[0, 2:302]
    if denom > 0:
        tpvecs[k] = [tpvecs[k][i] / denom for i in range(300)]

# %%
tpvecs
# Out:
# {'a': [-0.026771428571428568,
#   -0.04698571428571428,
#   0.06342857142857142,
#   -0.04728571428571428,
#   -0.003757142857142857,
#   0.007528571428571429,
#   0.008494117647058822,
#   -0.0037294117647058813,
#   -0.03790588235294118,
#   -0.002758823529411765,
#   0.05660588235294117,
#   -0.03672941176470589,
#   0.004447058823529411,
#   0.005952941176470589,
#   0.016776470588235295,
#   0.04094117647058823,
#   0.028494117647058823,
#   0.13742941176470586,
#   0.031641176470588235,
#   0.07742352941176472,
#   0.048747058823529414,
#   -0.08773529411764706,
#   0.03744705882352941,
#   -0.011505882352941178,
#   0.030070588235294116,
#   0.013864705882352942,
#   0.010529411764705883,
#   0.03048235294117647,
#   -0.011376470588235293,
#   -0.015517647058823528,
#   0.01635294117647059,
#   -0.06504705882352942,
#   -0.05197647058823529,
#   -0.01188235294117647,
#   -0.0014352941176470591,
#   0.005311764705882353,
#   0.055941176470588244,
#   -0.009894117647058826,
#   0.018058823529411763,
#   0.05987058823529412,
#   -0.01146470588235294,
#   -0.026064705882352945,
#   0.016082352941176468,
#   0.030711764705882355]}

# %%
# https://stackoverflow.com/questions/18424228/cosine-similarity-between-2-number-lists

def cosinesimilarity(xs : [int], ys : [int]):
    return np.dot(xs,ys)/(np.linalg.norm(xs)*np.linalg.norm(ys))

# %%
tokidict['linja']
# Out:
# ['elongated',
#  'oblong',
#  'long',
#  'long and flexible thing; string',
#  'rope',
#  'hair',
#  'thread',
#  'cord',
#  'chain',
#  'line',
#  'yarn']

# %% [markdown]
# PCA
# src: https://builtin.com/data-science/step-step-explanation-principal-component-analysis
# 1. Find mean and standard deviation of each parameter in big-dimensional space.
# 2. Find covariance of each pair of attributes
#    - (cov(x,y) = sum((x_i - x_m) * (y_i - y_m)) / n )
#    - Positive covariance -> x goes up when y goes up and vice versa
#    - Negative covariance -> x goes down when y goes up and vice versa
# 3. Find eigenvectors of resulting matrix with
#    largest eigenvalues
# 4. Recast initial data with those eigenvectors
#    as axes

# %%
def transpose(xss):
    ssx = []
    fs,*rs = xss
    for x in fs:
        ssx.append([x])
    for xs in rs:
        c=0
        for x in xs:
            ssx[c].append(x)
            c+=1
    return ssx

# %%
means = []
stdevs = []
for i in range(300):
    mean  = 0
    for k in tpvecs.keys():
        mean += tpvecs[k][i]
    mean /= len(tpvecs)
    means.append(mean)
for i in range(300):
    sumstdev = 0
    for k in tpvecs.keys():
        sumstdev += tpvecs[k][i] ** 2
    sumstdev /= len(tpvecs)
    stdevs.append(sumstdev ** 0.5)





covmatrix = []
for x in range(300):
    covmatrix.append([])
    for y in range(300):
        meanx = means[x]
        meany = means[y]
        summ = 0
        for k in tp_vocab:
            summ += ((tpvecs[k][x] - meanx) * (tpvecs[k][y] - meany))
        covmatrix[-1].append(summ)

eigens = np.linalg.eig(covmatrix)
eigenvalues = list([(eigens[0][y], y) for y in range(300)])
eigenvectors = list(eigens[1])

sortedeigenvalues = sorted(enumerate(eigenvalues), key=lambda x: x[1], reverse=True)
top_10_indices = [index for index, _ in sortedeigenvalues[:10]]
feature_vectors = [eigenvectors[i] for i in top_10_indices]


feature_vectors = feature_vectors
# sortedeigenvalues


tpvecsmatrix = []
for k in tp_vocab:
    tpvecsmatrix.append(tpvecs[k])
tpvecsmatrix = transpose(tpvecsmatrix)

len(tpvecsmatrix), len(tpvecsmatrix[0])

pca_reduced_dimensions = np.matmul(feature_vectors, tpvecsmatrix)

pca_reduced_dimensions = transpose(pca_reduced_dimensions)

# %%
len(pca_reduced_dimensions), len(pca_reduced_dimensions[0])
# Out:
# (154, 10)

# %%
words = (nouns + verbs + adjcs + advbs + preps + conjs)
np.random.shuffle(words)
for word in words[0:250]:
    l = list(word2vec[word2vec.word == word].to_numpy())
    if len(l) > 0:
        trialvec = l[0][2:302]
    reduced = np.matmul(feature_vectors,trialvec)
    distmeasures = []
    for t in range(len(tp_vocab)):
        dm = 0
        for i,p in enumerate(reduced):
            re = (np.real(pca_reduced_dimensions[t][i]) - np.real(p)) ** 2
            im = (np.imag(pca_reduced_dimensions[t][i]) - np.imag(p)) ** 2
            dm += (re+im)
        distmeasures.append((tp_vocab[t], dm))
    distmeasures
    print(word, [(x[0],round(x[1],3)) for x in sorted(distmeasures, key=lambda x: x[1])[0:3]])
# Out:
# music [('usawi', 0.042), ('kalama', 0.044), ('len', 0.047)]
# competition [('kulupu', 0.026), ('alasa', 0.026), ('sin', 0.029)]
# indicate [('selo', 0.017), ('weka', 0.022), ('waleja', 0.025)]
# mandate [('pana', 0.029), ('utala', 0.03), ('ken', 0.032)]
# scientific [('utala', 0.013), ('pana', 0.014), ('kulupu', 0.014)]
# entrance [('o', 0.009), ('la', 0.013), ('mu', 0.013)]
# wheat [('pan', 0.03), ('kili', 0.046), ('kasi', 0.047)]
# raw [('moku', 0.019), ('seli', 0.022), ('lete', 0.027)]
# particularly [('taso', 0.009), ('ala', 0.011), ('seme', 0.011)]
# couple [('mije', 0.018), ('taso', 0.019), ('pata', 0.023)]
# count [('nanpa', 0.009), ('ko', 0.013), ('tu', 0.018)]
# elbow [('sinpin', 0.006), ('palisa', 0.016), ('monsi', 0.019)]
# presumably [('ni', 0.016), ('anu', 0.017), ('ala', 0.019)]
# conduct [('pana', 0.014), ('ken', 0.021), ('pali', 0.022)]
# powerful [('ale', 0.024), ('wawa', 0.025), ('suno', 0.031)]
# assault [('weka', 0.021), ('utala', 0.024), ('ken', 0.027)]
# lower [('ekon', 0.008), ('anpa', 0.017), ('tawa', 0.018)]
# history [('palisa', 0.011), ('sike', 0.013), ('lupa', 0.013)]
# revolutionary [('olin', 0.011), ('kon', 0.021), ('monsuta', 0.022)]
# deal [('esun', 0.015), ('amin', 0.017), ('mani', 0.024)]
# prisoner [('kulupu', 0.025), ('pake', 0.026), ('lawa', 0.026)]
# expected [('kama', 0.014), ('ona', 0.017), ('seme', 0.017)]
# amendment [('moli', 0.027), ('o', 0.028), ('toki', 0.029)]
# eye [('uta', 0.008), ('sinpin', 0.012), ('oko', 0.013)]
# player [('lipu', 0.016), ('oko', 0.02), ('kiwen', 0.02)]
# exploration [('alasa', 0.026), ('ekon', 0.03), ('tawa', 0.033)]
# scale [('ko', 0.025), ('wan', 0.026), ('nanpa', 0.03)]
# virtually [('taso', 0.029), ('ali', 0.034), ('seme', 0.042)]
# airport [('nasin', 0.013), ('o', 0.014), ('toki', 0.017)]
# link [('kepen', 0.014), ('kipisi', 0.015), ('nasin', 0.016)]
# call [('pipi', 0.014), ('utala', 0.018), ('nasara', 0.024)]
# terribly [('pilin', 0.016), ('kin', 0.019), ('ali', 0.023)]
# sun [('suno', 0.011), ('naja', 0.011), ('mun', 0.018)]
# others [('taso', 0.028), ('jan', 0.031), ('ona', 0.033)]
# ribbon [('len', 0.033), ('linja', 0.039), ('leko', 0.039)]
# hence [('ni', 0.008), ('ala', 0.008), ('anu', 0.013)]
# consistent [('ko', 0.018), ('jelo', 0.019), ('ojele', 0.02)]
# challenge [('alasa', 0.014), ('soko', 0.014), ('pana', 0.019)]
# bear [('ipa', 0.017), ('meso', 0.017), ('suli', 0.018)]
# thought [('ike', 0.009), ('jan', 0.013), ('ala', 0.013)]
# bind [('palisa', 0.026), ('linja', 0.03), ('sinpin', 0.033)]
# assessment [('pana', 0.016), ('pali', 0.024), ('kepen', 0.029)]
# smoke [('nasara', 0.017), ('kon', 0.019), ('nasin', 0.02)]
# opponent [('uta', 0.014), ('tu', 0.019), ('kala', 0.019)]
# cloud [('pimeja', 0.013), ('walo', 0.024), ('telo', 0.026)]
# regret [('olin', 0.026), ('apeja', 0.029), ('akan', 0.04)]
# initiative [('sin', 0.021), ('utala', 0.021), ('kulupu', 0.023)]
# dance [('sike', 0.026), ('kalama', 0.028), ('mun', 0.028)]
# screw [('palisa', 0.033), ('linja', 0.033), ('oko', 0.036)]
# supply [('mani', 0.024), ('esun', 0.031), ('moku', 0.038)]
# prosecutor [('o', 0.018), ('nimi', 0.019), ('lipu', 0.021)]
# composition [('kule', 0.026), ('ko', 0.026), ('kiwen', 0.028)]
# inevitable [('pilin', 0.015), ('ike', 0.015), ('wile', 0.016)]
# possession [('musi', 0.026), ('sijelo', 0.031), ('kosan', 0.033)]
# form [('palisa', 0.007), ('tenpo', 0.008), ('noka', 0.01)]
# southeast [('naja', 0.019), ('nena', 0.02), ('pimeja', 0.02)]
# escape [('ekon', 0.022), ('tawa', 0.028), ('utala', 0.033)]
# outsider [('musi', 0.016), ('majuna', 0.018), ('mama', 0.02)]
# instant [('lo', 0.019), ('kin', 0.02), ('mi', 0.02)]
# stiff [('monsi', 0.022), ('sinpin', 0.022), ('nena', 0.028)]
# consideration [('namako', 0.019), ('sin', 0.02), ('pana', 0.021)]
# spokesman [('nimi', 0.032), ('toki', 0.034), ('nasin', 0.037)]
# administer [('pali', 0.029), ('pana', 0.029), ('jo', 0.035)]
# celebrate [('musi', 0.017), ('o', 0.018), ('mama', 0.024)]
# afraid [('lape', 0.022), ('monsuta', 0.024), ('pilin', 0.025)]
# willingness [('olin', 0.023), ('namako', 0.025), ('musi', 0.026)]
# wooden [('len', 0.039), ('usawi', 0.044), ('majuna', 0.046)]
# refuse [('pana', 0.02), ('jaki', 0.027), ('nasara', 0.027)]
# bolt [('linja', 0.014), ('palisa', 0.015), ('sike', 0.016)]
# struggle [('utala', 0.018), ('lape', 0.023), ('monsi', 0.023)]
# official [('nimi', 0.012), ('o', 0.029), ('ijo', 0.032)]
# damage [('pakala', 0.025), ('ken', 0.027), ('lete', 0.034)]
# payment [('esun', 0.016), ('mani', 0.026), ('kemu', 0.04)]
# enable [('ken', 0.01), ('ante', 0.013), ('pana', 0.013)]
# disc [('linja', 0.012), ('kemu', 0.013), ('len', 0.019)]
# swell [('nena', 0.03), ('enko', 0.033), ('lete', 0.033)]
# barely [('ona', 0.013), ('taso', 0.025), ('seme', 0.028)]
# advance [('soko', 0.024), ('alasa', 0.028), ('utala', 0.03)]
# horse [('waso', 0.021), ('po', 0.026), ('sa', 0.027)]
# apply [('kepen', 0.018), ('pana', 0.029), ('amin', 0.032)]
# true [('kin', 0.015), ('mun', 0.016), ('kalama', 0.021)]
# complain [('kantu', 0.018), ('sin', 0.026), ('kalama', 0.032)]
# poster [('nimi', 0.047), ('mije', 0.061), ('len', 0.068)]
# depth [('enko', 0.031), ('kiwen', 0.054), ('jeno', 0.056)]
# French [('enko', 0.031), ('kiwen', 0.054), ('jeno', 0.056)]
# frequent [('musi', 0.009), ('monsuta', 0.01), ('sijelo', 0.01)]
# ski [('poki', 0.016), ('pona', 0.017), ('en', 0.017)]
# ban [('nasara', 0.019), ('jaki', 0.027), ('moli', 0.027)]
# bankruptcy [('amin', 0.011), ('mani', 0.016), ('en', 0.02)]
# net [('ekon', 0.021), ('pake', 0.023), ('tawa', 0.028)]
# secure [('jeno', 0.01), ('ekon', 0.011), ('noka', 0.013)]
# feel [('pilin', 0.013), ('kin', 0.029), ('akan', 0.029)]
# mainly [('po', 0.01), ('sa', 0.012), ('poka', 0.015)]
# essence [('kalama', 0.022), ('mun', 0.024), ('nasin', 0.024)]
# psychology [('olin', 0.026), ('konwe', 0.029), ('monsuta', 0.029)]
# regard [('nasin', 0.015), ('olin', 0.016), ('monsuta', 0.016)]
# gesture [('o', 0.013), ('sitelen', 0.015), ('toki', 0.017)]
# formerly [('po', 0.018), ('poka', 0.022), ('majuna', 0.023)]
# bold [('waso', 0.027), ('walo', 0.033), ('o', 0.036)]
# journal [('tomo', 0.024), ('kulupu', 0.025), ('utala', 0.027)]
# admire [('olin', 0.043), ('musi', 0.048), ('namako', 0.05)]
# initially [('ona', 0.01), ('taso', 0.016), ('seme', 0.021)]
# objection [('nasara', 0.022), ('nimi', 0.027), ('o', 0.028)]
# noise [('kalama', 0.013), ('jaki', 0.024), ('kute', 0.033)]
# public [('sin', 0.021), ('kulupu', 0.023), ('kantu', 0.026)]
# demonstrate [('jeno', 0.01), ('nasin', 0.011), ('waleja', 0.012)]
# pressure [('ojele', 0.038), ('anpa', 0.041), ('amin', 0.043)]
# stable [('en', 0.012), ('mute', 0.012), ('mi', 0.012)]
# pump [('ojele', 0.024), ('ilo', 0.026), ('amin', 0.026)]
# trait [('o', 0.02), ('musi', 0.021), ('mama', 0.021)]
# mystery [('waso', 0.014), ('sewi', 0.015), ('usawi', 0.017)]
# persist [('ekon', 0.013), ('tawa', 0.017), ('utala', 0.019)]
# boil [('telo', 0.014), ('seli', 0.018), ('lete', 0.028)]
# monkey [('soweli', 0.029), ('len', 0.051), ('waso', 0.053)]
# expert [('la', 0.017), ('mu', 0.017), ('lipu', 0.018)]
# completely [('ali', 0.028), ('taso', 0.031), ('ni', 0.035)]
# astronomer [('sike', 0.015), ('supa', 0.02), ('suli', 0.022)]
# light [('suno', 0.025), ('pimeja', 0.033), ('pika', 0.037)]
# care [('sin', 0.029), ('jo', 0.03), ('ekon', 0.031)]
# versus [('pake', 0.018), ('nanpa', 0.019), ('tu', 0.02)]
# evolve [('utala', 0.01), ('tawa', 0.012), ('ekon', 0.016)]
# flow [('ojele', 0.036), ('anpa', 0.041), ('enko', 0.042)]
# compel [('ken', 0.026), ('selo', 0.027), ('kosan', 0.027)]
# status [('utala', 0.02), ('o', 0.02), ('lawa', 0.02)]
# parade [('o', 0.012), ('waso', 0.013), ('la', 0.015)]
# crack [('selo', 0.013), ('pakala', 0.015), ('kon', 0.018)]
# put [('palisa', 0.016), ('nanpa', 0.017), ('kepen', 0.019)]
# resign [('o', 0.044), ('ken', 0.045), ('pana', 0.047)]
# draw [('lupa', 0.028), ('palisa', 0.033), ('open', 0.037)]
# beg [('utala', 0.021), ('ken', 0.023), ('moli', 0.023)]
# kiss [('ali', 0.019), ('uta', 0.022), ('mije', 0.027)]
# portray [('sitelen', 0.015), ('nimi', 0.026), ('o', 0.034)]
# stuff [('ijo', 0.022), ('kepen', 0.024), ('esun', 0.025)]
# wise [('ma', 0.012), ('namako', 0.016), ('sona', 0.018)]
# bit [('pali', 0.003), ('tan', 0.004), ('weka', 0.004)]
# Mexican [('pali', 0.003), ('tan', 0.004), ('weka', 0.004)]
# north [('nena', 0.017), ('pimeja', 0.019), ('naja', 0.021)]
# diagnose [('amin', 0.034), ('uta', 0.035), ('pali', 0.036)]
# drain [('open', 0.022), ('telo', 0.025), ('anpa', 0.027)]
# middle [('sike', 0.011), ('mun', 0.014), ('poka', 0.015)]
# protection [('utala', 0.013), ('moli', 0.018), ('kosan', 0.02)]
# reply [('nasara', 0.025), ('jaki', 0.027), ('pana', 0.027)]
# joke [('kantu', 0.019), ('nimi', 0.028), ('toki', 0.033)]
# invade [('kosan', 0.036), ('alasa', 0.037), ('selo', 0.038)]
# earnings [('mani', 0.022), ('esun', 0.026), ('asite', 0.041)]
# sort [('weka', 0.012), ('pali', 0.013), ('sin', 0.014)]
# smoke [('nasara', 0.017), ('kon', 0.019), ('nasin', 0.02)]
# salmon [('ni', 0.015), ('nasara', 0.026), ('ala', 0.029)]
# dog [('soweli', 0.016), ('kulupu', 0.028), ('tomo', 0.032)]
# transportation [('ekon', 0.031), ('kepen', 0.034), ('amin', 0.035)]
# stadium [('sewi', 0.008), ('pini', 0.009), ('tan', 0.009)]
# fixed [('linja', 0.016), ('tu', 0.017), ('awase', 0.018)]
# creativity [('musi', 0.023), ('namako', 0.035), ('mama', 0.036)]
# necessary [('ala', 0.01), ('wile', 0.011), ('weka', 0.012)]
# production [('esun', 0.012), ('mani', 0.017), ('pana', 0.025)]
# affair [('o', 0.016), ('ken', 0.017), ('pona', 0.018)]
# drink [('moku', 0.012), ('suwi', 0.028), ('jami', 0.031)]
# shoulder [('sinpin', 0.013), ('monsi', 0.013), ('nena', 0.019)]
# involve [('weka', 0.01), ('pali', 0.013), ('pana', 0.014)]
# Russian [('weka', 0.01), ('pali', 0.013), ('pana', 0.014)]
# respectively [('po', 0.01), ('sa', 0.011), ('meso', 0.014)]
# power [('naja', 0.021), ('pika', 0.021), ('kon', 0.022)]
# understanding [('sona', 0.01), ('pilin', 0.013), ('akan', 0.014)]
# push [('ekon', 0.017), ('jeno', 0.017), ('palisa', 0.019)]
# appeal [('sin', 0.026), ('pana', 0.026), ('weka', 0.029)]
# value [('esun', 0.019), ('asite', 0.022), ('mani', 0.027)]
# works [('kemu', 0.021), ('mani', 0.023), ('ilo', 0.026)]
# sword [('linja', 0.025), ('sitelen', 0.036), ('palisa', 0.037)]
# wrap [('kipisi', 0.008), ('leko', 0.01), ('linja', 0.012)]
# cook [('ko', 0.015), ('nanpa', 0.017), ('jelo', 0.018)]
# well [('ona', 0.019), ('seme', 0.022), ('taso', 0.025)]
# wisdom [('olin', 0.047), ('ale', 0.048), ('naja', 0.049)]
# commit [('pana', 0.036), ('o', 0.038), ('nasin', 0.039)]
# attorney [('kosan', 0.034), ('lipu', 0.037), ('lawa', 0.038)]
# night [('waso', 0.011), ('puwa', 0.011), ('suli', 0.015)]
# journalism [('kosan', 0.025), ('utala', 0.034), ('lipu', 0.034)]
# produce [('mani', 0.018), ('asite', 0.023), ('pana', 0.025)]
# aware [('jan', 0.016), ('pilin', 0.017), ('wile', 0.019)]
# kiss [('ali', 0.019), ('uta', 0.022), ('mije', 0.027)]
# consciousness [('akan', 0.021), ('pilin', 0.025), ('konwe', 0.033)]
# measurement [('kipisi', 0.032), ('ko', 0.032), ('ojele', 0.032)]
# boat [('tenpo', 0.011), ('pakala', 0.014), ('pona', 0.015)]
# relative [('pake', 0.011), ('awen', 0.015), ('tu', 0.016)]
# Japanese [('pake', 0.011), ('awen', 0.015), ('tu', 0.016)]
# chaos [('apeja', 0.025), ('powe', 0.028), ('akan', 0.029)]
# rational [('apeja', 0.013), ('ike', 0.019), ('nasa', 0.019)]
# day [('jami', 0.009), ('suwi', 0.01), ('namako', 0.013)]
# reform [('utala', 0.018), ('nasin', 0.02), ('toki', 0.021)]
# OK [('utala', 0.018), ('nasin', 0.02), ('toki', 0.021)]
# grave [('kosan', 0.023), ('sitelen', 0.034), ('palisa', 0.039)]
# alternative [('pana', 0.031), ('ijo', 0.032), ('kepen', 0.034)]
# pause [('pakala', 0.011), ('tawa', 0.012), ('lukin', 0.014)]
# deeply [('wawa', 0.016), ('pilin', 0.021), ('kon', 0.021)]
# sprinkle [('pimeja', 0.018), ('suno', 0.02), ('nasara', 0.021)]
# intention [('o', 0.009), ('nasin', 0.015), ('toki', 0.015)]
# reward [('esun', 0.018), ('kulupu', 0.018), ('pana', 0.021)]
# poem [('sitelen', 0.018), ('o', 0.023), ('toki', 0.027)]
# resolution [('nasara', 0.017), ('nasin', 0.018), ('wan', 0.02)]
# warn [('jaki', 0.017), ('utala', 0.018), ('tawa', 0.019)]
# major [('sama', 0.017), ('mi', 0.018), ('uta', 0.019)]
# volume [('ojele', 0.027), ('pika', 0.03), ('enko', 0.031)]
# leg [('monsi', 0.04), ('sinpin', 0.042), ('nena', 0.048)]
# persuade [('ken', 0.019), ('pana', 0.023), ('ante', 0.023)]
# reportedly [('sama', 0.012), ('ali', 0.012), ('jan', 0.012)]
# elect [('ken', 0.02), ('pana', 0.021), ('ante', 0.025)]
# trailer [('toki', 0.009), ('nasin', 0.01), ('ilo', 0.013)]
# operating [('mani', 0.017), ('lo', 0.026), ('kute', 0.029)]
# refrigerator [('lo', 0.02), ('asite', 0.023), ('kute', 0.024)]
# forgive [('apeja', 0.019), ('akan', 0.028), ('toki', 0.036)]
# nominee [('o', 0.027), ('pana', 0.03), ('nimi', 0.031)]
# comfort [('sona', 0.03), ('lape', 0.03), ('wawa', 0.032)]
# curve [('linja', 0.032), ('sike', 0.044), ('leko', 0.047)]
# ready [('telo', 0.011), ('pona', 0.011), ('sina', 0.012)]
# originally [('poka', 0.01), ('po', 0.013), ('sa', 0.018)]
# weapon [('toki', 0.013), ('o', 0.014), ('lipu', 0.014)]
# era [('sewi', 0.008), ('mun', 0.012), ('sike', 0.012)]
# gather [('kasi', 0.019), ('alasa', 0.024), ('soko', 0.034)]
# frame [('sitelen', 0.02), ('palisa', 0.024), ('linja', 0.026)]
# answer [('pana', 0.022), ('ante', 0.022), ('kepen', 0.022)]
# external [('jan', 0.016), ('ipa', 0.019), ('ijo', 0.019)]
# conclusion [('nasara', 0.009), ('kepen', 0.016), ('waleja', 0.018)]
# road [('nasin', 0.017), ('kalama', 0.017), ('len', 0.019)]
# trail [('nasara', 0.027), ('mun', 0.027), ('pimeja', 0.028)]
# feature [('lipu', 0.011), ('lawa', 0.012), ('utala', 0.012)]
# cave [('nena', 0.012), ('suli', 0.012), ('kiwen', 0.013)]
# black [('laso', 0.019), ('loje', 0.021), ('jelo', 0.026)]
# breath [('lukin', 0.021), ('pakala', 0.021), ('kama', 0.025)]
# architecture [('leko', 0.044), ('la', 0.044), ('mu', 0.044)]
# menu [('ijo', 0.027), ('mani', 0.028), ('kepen', 0.03)]
# false [('powe', 0.007), ('ike', 0.029), ('ale', 0.034)]
# describe [('waleja', 0.017), ('ijo', 0.024), ('weka', 0.026)]
# wage [('esun', 0.025), ('mani', 0.032), ('tomo', 0.045)]
# away [('kama', 0.019), ('seme', 0.021), ('ona', 0.022)]
# stove [('ko', 0.019), ('en', 0.02), ('ojele', 0.02)]
# therapist [('sijelo', 0.058), ('insa', 0.058), ('sona', 0.067)]
# hard [('telo', 0.013), ('anpa', 0.016), ('wawa', 0.017)]
# conviction [('apeja', 0.021), ('powe', 0.026), ('nasin', 0.026)]
# already [('taso', 0.007), ('seme', 0.012), ('ona', 0.012)]
# south [('nena', 0.028), ('soko', 0.032), ('waso', 0.033)]
# coal [('ko', 0.037), ('ojele', 0.043), ('asite', 0.046)]
# scene [('nasara', 0.009), ('waleja', 0.012), ('weka', 0.013)]
# interval [('anpa', 0.009), ('noka', 0.011), ('kiwen', 0.012)]
# stare [('oko', 0.012), ('lawa', 0.015), ('lukin', 0.016)]
# construct [('kipisi', 0.015), ('jeno', 0.017), ('lupa', 0.02)]
# designer [('musi', 0.022), ('tomo', 0.023), ('la', 0.025)]
# before [('ona', 0.011), ('seme', 0.025), ('kama', 0.027)]
# various [('jo', 0.026), ('lili', 0.03), ('mute', 0.03)]
# classify [('pana', 0.019), ('nasara', 0.025), ('ken', 0.031)]
# handle [('kemu', 0.01), ('kiwen', 0.012), ('palisa', 0.013)]
# prosecution [('nimi', 0.033), ('pana', 0.034), ('nasara', 0.035)]

# %%
ns = [np.random.randint(300) for i in range(10)]
for n in ns:
    print(tpvecs['nena'][n])
    print(tpvecs['supa'][n])
# Out:
# -0.0020461538461538455
# 0.009510000000000001
# -0.030369230769230766
# -0.03626
# -0.004815384615384615
# -0.018979999999999997
# -0.0187
# 0.0004099999999999979
# -0.021107692307692313
# -0.02015
# -0.009084615384615385
# -0.000669999999999999
# -0.03813076923076923
# 0.006520000000000001
# 0.0070846153846153845
# -0.020499999999999997
# 0.0034307692307692307
# -0.04161000000000001
# 0.014492307692307691
# 0.00936

# %%
tokidict['akesi']
# Out:
# ['reptile', 'amphibian']

# %%
tp_vocab = toki.TOKI.drop_duplicates().tolist()

# %%
''.join(['t','elep','hone'])
# Out:
# 'telephone'

# %%
# From http://www.textfixer.com/resources/common-english-words.txt
bannedWords = "a,able,about,across,after,all,almost,also,am,among,an,and,any,are,as,at,be,because,been,but,by,can,cannot,could,dear,did,do,does,either,else,ever,every,for,from,get,got,had,has,have,he,her,hers,him,his,how,however,i,if,in,into,is,it,its,just,least,let,like,likely,may,me,might,most,must,my,neither,no,nor,not,of,off,often,on,only,or,other,our,own,rather,said,say,says,she,should,since,so,some,than,that,the,their,them,then,there,these,they,this,tis,to,too,twas,us,wants,was,we,were,what,when,where,which,while,who,whom,why,will,with,would,yet,you,your".split(",")

# %%
from matplotlib import pyplot as plt

# %%
data = np.array()
m, n = data.shape
np.random.shuffle(data) # shuffle before splitting into dev and training sets

data_dev = data[0:1000].T
Y_dev = data_dev[0]
X_dev = data_dev[1:n]
X_dev = X_dev / 255.

data_train = data[1000:m].T
Y_train = data_train[0]
X_train = data_train[1:n]
X_train = X_train / 255.
_,m_train = X_train.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20096\3417625827.py in <module>
# ----> 1 data = np.array()
#       2 m, n = data.shape
#       3 np.random.shuffle(data) # shuffle before splitting into dev and training sets
#       4
#       5 data_dev = data[0:1000].T
#
# TypeError: array() missing required argument 'object' (pos 0)

# %%
tokisentences
# Out:
#                                                     toki  \
# 0                                                mi suli
# 1                                                mi suli
# 2                                                mi suli
# 3                                                mi suli
# 4                            kili li tawa anpa poka kasi
# ...                                                  ...
# 25532        tenpo pi mute lili la ijo ike li kama e jan
# 25533   tenpo pi mute lili la ijo ike il kama e jan pona
# 25534  ona li weka e kon tawa soweli kepeken luka lon...
# 25535              mi mute li awen ala lon tomo tan seme
# 25536          mije pi meli lili mi li pona tawa mi mute
#
#                                            english
# 0                                        I am tall
# 1                                     Im important
# 2                                           Im fat
# 3                                           Im big
# 4        The apple does not fall far from the tree
# ...                                            ...
# 25532        Sometimes bad things happen to people
# 25533   Sometimes bad things happen to good people
# 25534                          She strangled a cat
# 25535                        Why dont we stay home
# 25536                       We like our son-in-law
#
# [25537 rows x 2 columns]

# %%
from collections import defaultdict


    
        
class QTable:
    def __init__(self, states, targetVisits, discount, rateConstant):
        self.q      = [[0] * len(states)] * len(states)
        self.visits = [[0] * len(states)] * len(states)
        self.targetVisits = targetVisits
        self.d  = discount
        self.rc = rateConstant
        self.ls = 0
        self.la = 0

# %%
class DTNode:


    class DTLeaf:
        def __init__(self, ls : list[int]):
            self.label = ls
        def classify(self, v : float):
            return self.label
        def addAllLabels(self, sl : set(int)):
            sl.add(self.label)

    class DTInterior:
        def __init__(self, leftSubtree, rightSubtree, decisionFeature, maxFeatureValue, getFeatureValue, successor):
            self.leftSubtree = leftSubtree
            self.rightSubtree = rightSubtree
            self.decisionFeature = decisionFeature
            self.maxFeatureValue = maxFeatureValue
            self.getFeatureValue = getFeatureValue
            self.successor       = successor
        
        def classify(self, v):
            if self.maxFeatureValue < self.getFeatureValue(v, self.decisionFeature):
                return self.rightSubtree.classify(v)
            else:
                return self.leftSubtree.classify(v)

        def addAllLabels(self, sl):
            self.leftSubtree.addAllLabels(sl)
            self.rightSubtree.addAllLabels(sl)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20096\745867550.py in <module>
# ----> 1 class DTNode:
#       2
#       3
#       4     class DTLeaf:
#       5         def __init__(self, ls : list[int]):
#
# ~\AppData\Local\Temp\ipykernel_20096\745867550.py in DTNode()
#       2
#       3
# ----> 4     class DTLeaf:
#       5         def __init__(self, ls : list[int]):
#       6             self.label = ls
#
# ~\AppData\Local\Temp\ipykernel_20096\745867550.py in DTLeaf()
#       7         def classify(self, v : float):
#       8             return self.label
# ----> 9         def addAllLabels(self, sl : set(int)):
#      10             sl.add(self.label)
#      11
#
# TypeError: 'type' object is not iterable

# %%
# data = dictionary of english string to toki pona sequence

def splitOn(data: dict, feature, featureValue, getFeatureValue):
    less = dict()
    more = dict()
    for k in data.keys():
        if getFeatureValue(k) > getFeatureValue:
            more[k] = data[k]
        else:
            less[k] = data[k]
    return (more, less)

# %%
def gini(data : dict):
    g = 0
    lbs = Histogram()
    for k in data.keys():
        lbs.inc(data[k])
    for l in lbs.hg.keys():
        p_i = lbs.getCountFor(l) / len(data)
        g += p_i * p_i
    return 1 - g

def gain(parent, child1, child2):
    return gini(parent) - gini(child1) - gini(child2)

# %%
def train(data : dict):
    if len(data.keys()) == 1:
        return data[data.keys()[0]]
    if len(data.keys()) == 0:
        return DTNode.DTLeaf([0])

# %%
# with open('tokisentences.txt', 'r') as l:
#     with open('output.txt', 'w') as f:
#         for line in l.readlines():
#             tokens = line.strip().split(',')
#             if len(tokens) == 2:
#                 output_string = ""
#                 for char in line:
#                     if char.isalpha() or char == '\n':
#                         output_string += char
#                 f.write(output_string)

# %%
from hmmlearn import hmm
from typing import *
import time

# %%
tokitoint = dict()
for i,w in enumerate(tp_vocab):
    tokitoint[w] = i

engtoint = dict()
for i,w in enumerate(freq.Word):
    engtoint[w] = i

# %%
tokidata = dict()
for index in range(len(tokisentences)):
    tp,en = str(tokisentences['toki'][index]),str(tokisentences['english'][index])
    if en[0] == ' ':
        en = en[1:]
    tpsep = tp.split()
    ts = []
    es = []
    n=False
    for t in tpsep:
        if t in tokitoint:
            ts.append(tokitoint[t])
        else:
            n=True
    if not n:
        tokidata[en] = ts

# %%
engcoder = dict()
for i,c in enumerate(" abcdefghijklmnopqrstuvwxyz"):
    engcoder[c] = i

# %%
def build_model_score(num_states: int, training_sequence: List[int]) -> Tuple[hmm.CategoricalHMM, float]:
    model = hmm.CategoricalHMM(n_components=num_states, n_iter=100)
    model.fit(training_sequence)
    return model, model.score(training_sequence)

# %% [markdown]
# # STATISTICAL MACHINE TRANSLATION
#
# $f$ = string in  given language, like "I love my cat."
#
# $e$ = string in target language, like "mi olin e soweli suno"
#
# We want to return whatever $e$ maximizes $p(e|f)$.
#
# Bayes' Theorem Micro: CS Edition shows us that $p(f|e)p(e)$ works here.

# %%
class Histogram:
    def __init__(self):
        self.hg = dict()

    def incby(self, key, n):
        if key not in self.hg:
            self.hg[key] = n
        else: 
            p = self.hg[key] 
            self.hg[key] = p + n

    def inc(self, key):
        self.incby(key,1)

    def getCountFor(self, value):
        if value not in self.hg:
            return 0        
        return self.hg[value]
    
    def getTotalCounts(self):
        total = 0
        for x in self.hg.keys():
            if x in self.hg:
                total += self.hg[x]
        return total

    def getPortionFor(self, value):
        return self.getCountFor(value) / self.getTotalCounts()

featuresbylabel = dict()
priors = Histogram()
for k in tokidata.keys():
    fs = k.split()
    
    for f in fs:
        for i in tokidata[k]:
            if i in featuresbylabel:
                featuresbylabel[i].inc(f)
            else:
                featuresbylabel[i] = Histogram()
                featuresbylabel[i].inc(f)
    for i in tokidata[k]:
        priors.inc(i)

def classify(w : str):
    m = 0,""
    for l in tokitoint.keys():
        if tokitoint[l] in featuresbylabel:
            v = featuresbylabel[tokitoint[l]].getPortionFor(w) 
            v /= priors.getCountFor(tokitoint[l])
            if v > m[0]:
                m = v,l
    return m[1]

classify('dog')
# Out:
# 'soweli'

# %%
print(f"nuts: {classify('nuts')}, dead: {classify('dead')}, music: {classify('music')}, grave: {classify('grave')}, sudden: {classify('sudden')}")
# Out:
# nuts: nasa, dead: moli, music: kalama, grave: , sudden:

# %%
featuresbylabel[75].hg
# Out:
# {'dead': 1,
#  'man': 1,
#  'I': 4,
#  'will': 1,
#  'die': 3,
#  'for': 1,
#  'you': 1,
#  'want': 3,
#  'to': 4,
#  'stay': 1,
#  'alive': 1,
#  'used': 1}

# %%
def filter_text(text: str) -> (str,int):
    result = " "
    lowerbet = "qwertyuiopasdfghjklzxcvbnm "
    upperbet = "QWERTYUIOPASDFGHJKLZXCVBNM"
    for c in text:
        if c in lowerbet:
            result += c
        elif c in upperbet:
            for i in range(26):
                if upperbet[i] == c:
                    result += lowerbet[i]
        else:
            continue
    return result
